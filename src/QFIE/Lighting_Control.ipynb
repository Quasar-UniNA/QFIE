# %% [markdown]
# # QFIE For Lighting Controller System
# This notebook aims to illustrate how QFIE can control efficiently a lighting system, in  which  the  control system dim the bulb light automatically according to the environmental Light. Two input variables are considered, namely the environment light and the  changing  rate of the environmental light. Finally, the control surface of the system will be obtained both using QFIE and the canonical Mamdani fuzzy system, which configuration is reported in the paper.
#
# Firstly, let us import the required libraries.

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
import FuzzyEngines as FE

# %% [markdown]
# The system is a MISO composed of two input variables and one output variable. In detail:
#
# Inputs:
#
# - Environment Light (env_light): three linguistic terms are considered: 'Dark', 'Medium', 'Light'
#
# - Changing Rate (change_rate): three lingiuistic terms are considered: 'Negative Small', 'Zero', 'Positive Small'
#
# Output:
#
# - Dimmer Control (dimmer_ctrl): four linguistic terms are considered: 'Very Small', 'Small', 'Big', 'Very Big'
#
#
# By running the following cell, the fuzzy sets used are graphically shown.

# %%
env_light = np.linspace(120, 220, 200)
changing_rate = np.linspace(-10, 10, 200)
dimmer_control = np.linspace(0, 10, 200)



l_dark = fuzz.trapmf(env_light, [120,120,130,150])
l_medium = fuzz.trapmf(env_light, [130,  150, 190,210])
l_light = fuzz.trapmf(env_light, [190,  210, 220, 220])

r_ns = fuzz.trimf(changing_rate, [-10,-10,0])
r_zero = fuzz.trimf(changing_rate, [-10,0,10])
r_ps = fuzz.trimf(changing_rate, [0,10,10])

dm_vs = fuzz.trapmf(dimmer_control, [0,0,2,4])
dm_s = fuzz.trimf(dimmer_control, [2,4,6])
dm_b = fuzz.trimf(dimmer_control, [4,6,8])
dm_vb = fuzz.trapmf(dimmer_control, [6,8,10,10])




# Visualize these universes and membership functions
fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(10, 12))


ax0.plot(env_light, l_dark, 'b', linewidth=1.5, label='dark')
ax0.plot(env_light, l_medium, 'g', linewidth=1.5, label='medium')
ax0.plot(env_light, l_light, 'r', linewidth=1.5, label='light')
ax0.set_title('Environment Light')
ax0.legend()

ax1.plot(changing_rate, r_ns, 'b', linewidth=1.5, label='negative small')
ax1.plot(changing_rate, r_zero, 'g', linewidth=1.5, label='zero')
ax1.plot(changing_rate, r_ps, 'r', linewidth=1.5, label='positive small')
ax1.set_title('Changing Rate')
ax1.legend()


ax2.plot(dimmer_control, dm_vs, 'b', linewidth=1.5, label='very small')
ax2.plot(dimmer_control, dm_s, 'g', linewidth=1.5, label='small')
ax2.plot(dimmer_control, dm_b, 'r', linewidth=1.5, label='big')
ax2.plot(dimmer_control, dm_vb, 'y', linewidth=1.5, label='very big')
ax2.set_title('Dimmer control')
ax2.legend()

# Turn off top/right axes
for ax in (ax0, ax1, ax2):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()


plt.show()

# %% [markdown]
# The rules base of the system is composed of the following rules:
#
# - if env_light is dark and change_rate is pos_small then dimmer_ctrl is big
# - if env_light is dark and change_rate is zero then dimmer_ctrl is big
# - if env_light is dark and change_rate is neg_small then dimmer_ctrl is very_big
# - if env_light is medium and change_rate is pos_small then dimmer_ctrl is small
# - if env_light is medium and change_rate is zero then dimmer_ctrl is big
# - if env_light is medium and change_rate is neg_small then dimmer_ctrl is big
# - if env_light is light and change_rate is pos_small then dimmer_ctrl is very_small
# - if env_light is light and change_rate is zero then dimmer_ctrl is small
# - if env_light is light and change_rate is neg_small then dimmer_ctrl is big
#
# By running the following two cells QFIE is properly initialized

# %%
'''rules = ['if env_light is dark and change_rate is pos_small then dimmer_ctrl is big',
         'if env_light is dark and change_rate is zero then dimmer_ctrl is big',
         'if env_light is dark and change_rate is neg_small then dimmer_ctrl is very_big',
         'if env_light is medium and change_rate is pos_small then dimmer_ctrl is small',
         'if env_light is medium and change_rate is zero then dimmer_ctrl is big',
         'if env_light is medium and change_rate is neg_small then dimmer_ctrl is big',
         'if env_light is light and change_rate is pos_small then dimmer_ctrl is very_small',
         'if env_light is light and change_rate is zero then dimmer_ctrl is small',
         'if env_light is light and change_rate is neg_small then dimmer_ctrl is big']

'''
rules = ['if env_light is dark and change_rate is not neg_small then dimmer_ctrl is big', 
         'if env_light is dark and change_rate is neg_small then dimmer_ctrl is very_big',
         'if env_light is medium and change_rate is not pos_small then dimmer_ctrl is big',
         'if env_light is medium and change_rate is pos_small then dimmer_ctrl is small',
         'if env_light is light and change_rate is pos_small then dimmer_ctrl is very_small',
         'if env_light is light and change_rate is zero then dimmer_ctrl is small',
         'if env_light is light and change_rate is neg_small then dimmer_ctrl is big']

# %%
qfie_linear = FE.QuantumFuzzyEngine(verbose=False, encoding='linear')
qfie_linear.input_variable(name='env_light', range=env_light)
qfie_linear.input_variable(name='change_rate', range=changing_rate)
qfie_linear.output_variable(name='dimmer_ctrl', range=dimmer_control)

qfie_linear.add_input_fuzzysets(var_name='env_light', set_names=['dark', 'medium', 'light'], sets=[l_dark, l_medium, l_light])
qfie_linear.add_input_fuzzysets(var_name='change_rate', set_names=['neg_small', 'zero', 'pos_small'], sets=[r_ns, r_zero, r_ps])
qfie_linear.add_output_fuzzysets(var_name='dimmer_ctrl', set_names=['very_small', 'small', 'big', 'very_big'],sets=[dm_vs, dm_s, dm_b, dm_vb])
qfie_linear.set_rules(rules)

qfie_log = FE.QuantumFuzzyEngine(verbose=False, encoding='logaritmic')
qfie_log.input_variable(name='env_light', range=env_light)
qfie_log.input_variable(name='change_rate', range=changing_rate)
qfie_log.output_variable(name='dimmer_ctrl', range=dimmer_control)

qfie_log.add_input_fuzzysets(var_name='env_light', set_names=['dark', 'medium', 'light'], sets=[l_dark, l_medium, l_light])
qfie_log.add_input_fuzzysets(var_name='change_rate', set_names=['neg_small', 'zero', 'pos_small'], sets=[r_ns, r_zero, r_ps])
qfie_log.add_output_fuzzysets(var_name='dimmer_ctrl', set_names=['very_small', 'small', 'big', 'very_big'],sets=[dm_vs, dm_s, dm_b, dm_vb])
qfie_log.set_rules(rules)

# %% [markdown]
# To obtain the control surface of QFIE, it is used to fire the rules in 121 different input combinations. In detail, for 11 values of env_light 11 different values of change_rate are considered. The 121 outputs obtained are collected in a list which will be used at the end of the notebook to plot the control surface.

# %%
from qiskit_ibm_runtime.fake_provider import FakeMumbaiV2

el_list, cr_list = [t for t in range(120, 230, 10)], [s for s in range(-10, 12, 2)]
f_quantum_linear, f_quantum_log = [], []
for el in el_list:
    for cr in cr_list:
        qfie_linear.build_inference_qc({'env_light':el, 'change_rate':cr}, draw_qc=False, distributed=True)
        f_quantum_linear.append(qfie_linear.execute(n_shots=5000,  transpile_info=True, plot_histo=False)[0])
        #qfie_log.build_inference_qc({'env_light':el, 'change_rate':cr}, draw_qc=False)
        #f_quantum_log.append(qfie_log.execute(n_shots=5000, transpile_info=True, plot_histo=False)[0])
# Out:
# transpiled depth qc very_small 3
# Operations very_small OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                ┌──────────────────────────────┐      ░
#   env_light_0: ┤0                             ├──────░────
#                │                              │      ░
#   env_light_1: ┤1 Initialize(0,1,0,0,0,0,0,0) ├──────░────
#                │                              │      ░
#   env_light_2: ┤2                             ├──■───░────
#                ├──────────────────────────────┤  │   ░
# change_rate_0: ┤0                             ├──┼───░────
#                │                              │  │   ░
# change_rate_1: ┤1 Initialize(0,1,0,0,0,0,0,0) ├──┼───░────
#                │                              │  │   ░
# change_rate_2: ┤2                             ├──■───░────
#                └──────────────────────────────┘┌─┴─┐ ░ ┌─┐
#    very_small: ────────────────────────────────┤ X ├─░─┤M├
#                                                └───┘ ░ └╥┘
#          c0: 1/═════════════════════════════════════════╩═
#                                                         0
# transpiled depth qc small 4
# Operations small OrderedDict([('initialize', 2), ('ccx', 2), ('barrier', 2), ('measure', 1)])
#                ┌──────────────────────────────┐      ░       ░
#   env_light_0: ┤0                             ├──────░───────░────
#                │                              │      ░       ░
#   env_light_1: ┤1 Initialize(0,1,0,0,0,0,0,0) ├──■───░───────░────
#                │                              │  │   ░       ░
#   env_light_2: ┤2                             ├──┼───░───■───░────
#                ├──────────────────────────────┤  │   ░   │   ░
# change_rate_0: ┤0                             ├──┼───░───┼───░────
#                │                              │  │   ░   │   ░
# change_rate_1: ┤1 Initialize(0,1,0,0,0,0,0,0) ├──┼───░───■───░────
#                │                              │  │   ░   │   ░
# change_rate_2: ┤2                             ├──■───░───┼───░────
#                └──────────────────────────────┘┌─┴─┐ ░ ┌─┴─┐ ░ ┌─┐
#         small: ────────────────────────────────┤ X ├─░─┤ X ├─░─┤M├
#                                                └───┘ ░ └───┘ ░ └╥┘
#          c1: 1/═════════════════════════════════════════════════╩═
#                                                                 0
# transpiled depth qc big 9
# Operations big OrderedDict([('x', 4), ('ccx', 3), ('barrier', 3), ('initialize', 2), ('measure', 1)])
#                ┌──────────────────────────────┐                ░           »
#   env_light_0: ┤0                             ├───────■────────░───────────»
#                │                              │       │        ░           »
#   env_light_1: ┤1 Initialize(0,1,0,0,0,0,0,0) ├───────┼────────░────────■──»
#                │                              │       │        ░        │  »
#   env_light_2: ┤2                             ├───────┼────────░────────┼──»
#                ├──────────────────────────────┤┌───┐  │  ┌───┐ ░        │  »
# change_rate_0: ┤0                             ├┤ X ├──■──┤ X ├─░────────┼──»
#                │                              │└───┘  │  └───┘ ░        │  »
# change_rate_1: ┤1 Initialize(0,1,0,0,0,0,0,0) ├───────┼────────░────────┼──»
#                │                              │       │        ░ ┌───┐  │  »
# change_rate_2: ┤2                             ├───────┼────────░─┤ X ├──■──»
#                └──────────────────────────────┘     ┌─┴─┐      ░ └───┘┌─┴─┐»
#           big: ─────────────────────────────────────┤ X ├──────░──────┤ X ├»
#                                                     └───┘      ░      └───┘»
#          c2: 1/════════════════════════════════════════════════════════════»
#                                                                            »
# «                     ░       ░
# «  env_light_0: ──────░───────░────
# «                     ░       ░
# «  env_light_1: ──────░───────░────
# «                     ░       ░
# «  env_light_2: ──────░───■───░────
# «                     ░   │   ░
# «change_rate_0: ──────░───■───░────
# «                     ░   │   ░
# «change_rate_1: ──────░───┼───░────
# «               ┌───┐ ░   │   ░
# «change_rate_2: ┤ X ├─░───┼───░────
# «               └───┘ ░ ┌─┴─┐ ░ ┌─┐
# «          big: ──────░─┤ X ├─░─┤M├
# «                     ░ └───┘ ░ └╥┘
# «         c2: 1/═════════════════╩═
# «                                0
# transpiled depth qc very_big 3
# Operations very_big OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                ┌──────────────────────────────┐      ░
#   env_light_0: ┤0                             ├──■───░────
#                │                              │  │   ░
#   env_light_1: ┤1 Initialize(0,1,0,0,0,0,0,0) ├──┼───░────
#                │                              │  │   ░
#   env_light_2: ┤2                             ├──┼───░────
#                ├──────────────────────────────┤  │   ░
# change_rate_0: ┤0                             ├──■───░────
#                │                              │  │   ░
# change_rate_1: ┤1 Initialize(0,1,0,0,0,0,0,0) ├──┼───░────
#                │                              │  │   ░
# change_rate_2: ┤2                             ├──┼───░────
#                └──────────────────────────────┘┌─┴─┐ ░ ┌─┐
#      very_big: ────────────────────────────────┤ X ├─░─┤M├
#                                                └───┘ ░ └╥┘
#          c3: 1/═════════════════════════════════════════╩═
#                                                         0
# transpiled depth qc very_small 3
# Operations very_small OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                      ┌──────────────────────────────┐            ░
#   env_light_0: ──────┤0                             ├────────────░────
#                      │                              │            ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────────░────
#                      │                              │            ░
#   env_light_2: ──────┤2                             ├────────■───░────
#                ┌─────┴──────────────────────────────┴─────┐  │   ░
# change_rate_0: ┤0                                         ├──┼───░────
#                │                                          │  │   ░
# change_rate_1: ┤1 Initialize(0,0.89443,0.44721,0,0,0,0,0) ├──┼───░────
#                │                                          │  │   ░
# change_rate_2: ┤2                                         ├──■───░────
#                └──────────────────────────────────────────┘┌─┴─┐ ░ ┌─┐
#    very_small: ────────────────────────────────────────────┤ X ├─░─┤M├
#                                                            └───┘ ░ └╥┘
#          c4: 1/═════════════════════════════════════════════════════╩═
#                                                                     0
# transpiled depth qc small 4
# Operations small OrderedDict([('initialize', 2), ('ccx', 2), ('barrier', 2), ('measure', 1)])
#                      ┌──────────────────────────────┐            ░       ░
#   env_light_0: ──────┤0                             ├────────────░───────░────
#                      │                              │            ░       ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────■───░───────░────
#                      │                              │        │   ░       ░
#   env_light_2: ──────┤2                             ├────────┼───░───■───░────
#                ┌─────┴──────────────────────────────┴─────┐  │   ░   │   ░
# change_rate_0: ┤0                                         ├──┼───░───┼───░────
#                │                                          │  │   ░   │   ░
# change_rate_1: ┤1 Initialize(0,0.89443,0.44721,0,0,0,0,0) ├──┼───░───■───░────
#                │                                          │  │   ░   │   ░
# change_rate_2: ┤2                                         ├──■───░───┼───░────
#                └──────────────────────────────────────────┘┌─┴─┐ ░ ┌─┴─┐ ░ ┌─┐
#         small: ────────────────────────────────────────────┤ X ├─░─┤ X ├─░─┤M├
#                                                            └───┘ ░ └───┘ ░ └╥┘
#          c5: 1/═════════════════════════════════════════════════════════════╩═
#                                                                             0
# transpiled depth qc big 9
# Operations big OrderedDict([('x', 4), ('ccx', 3), ('barrier', 3), ('initialize', 2), ('measure', 1)])
#                      ┌──────────────────────────────┐                      ░ »
#   env_light_0: ──────┤0                             ├─────────────■────────░─»
#                      │                              │             │        ░ »
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├─────────────┼────────░─»
#                      │                              │             │        ░ »
#   env_light_2: ──────┤2                             ├─────────────┼────────░─»
#                ┌─────┴──────────────────────────────┴─────┐┌───┐  │  ┌───┐ ░ »
# change_rate_0: ┤0                                         ├┤ X ├──■──┤ X ├─░─»
#                │                                          │└───┘  │  └───┘ ░ »
# change_rate_1: ┤1 Initialize(0,0.89443,0.44721,0,0,0,0,0) ├───────┼────────░─»
#                │                                          │       │        ░ »
# change_rate_2: ┤2                                         ├───────┼────────░─»
#                └──────────────────────────────────────────┘     ┌─┴─┐      ░ »
#           big: ─────────────────────────────────────────────────┤ X ├──────░─»
#                                                                 └───┘      ░ »
#          c6: 1/══════════════════════════════════════════════════════════════»
#                                                                              »
# «                               ░       ░
# «  env_light_0: ────────────────░───────░────
# «                               ░       ░
# «  env_light_1: ───────■────────░───────░────
# «                      │        ░       ░
# «  env_light_2: ───────┼────────░───■───░────
# «                      │        ░   │   ░
# «change_rate_0: ───────┼────────░───■───░────
# «                      │        ░   │   ░
# «change_rate_1: ───────┼────────░───┼───░────
# «               ┌───┐  │  ┌───┐ ░   │   ░
# «change_rate_2: ┤ X ├──■──┤ X ├─░───┼───░────
# «               └───┘┌─┴─┐└───┘ ░ ┌─┴─┐ ░ ┌─┐
# «          big: ─────┤ X ├──────░─┤ X ├─░─┤M├
# «                    └───┘      ░ └───┘ ░ └╥┘
# «         c6: 1/═══════════════════════════╩═
# «                                          0
# transpiled depth qc very_big 3
# Operations very_big OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                      ┌──────────────────────────────┐            ░
#   env_light_0: ──────┤0                             ├────────■───░────
#                      │                              │        │   ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────┼───░────
#                      │                              │        │   ░
#   env_light_2: ──────┤2                             ├────────┼───░────
#                ┌─────┴──────────────────────────────┴─────┐  │   ░
# change_rate_0: ┤0                                         ├──■───░────
#                │                                          │  │   ░
# change_rate_1: ┤1 Initialize(0,0.89443,0.44721,0,0,0,0,0) ├──┼───░────
#                │                                          │  │   ░
# change_rate_2: ┤2                                         ├──┼───░────
#                └──────────────────────────────────────────┘┌─┴─┐ ░ ┌─┐
#      very_big: ────────────────────────────────────────────┤ X ├─░─┤M├
#                                                            └───┘ ░ └╥┘
#          c7: 1/═════════════════════════════════════════════════════╩═
#                                                                     0
# transpiled depth qc very_small 3
# Operations very_small OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                      ┌──────────────────────────────┐           ░
#   env_light_0: ──────┤0                             ├───────────░────
#                      │                              │           ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├───────────░────
#                      │                              │           ░
#   env_light_2: ──────┤2                             ├───────■───░────
#                ┌─────┴──────────────────────────────┴────┐  │   ░
# change_rate_0: ┤0                                        ├──┼───░────
#                │                                         │  │   ░
# change_rate_1: ┤1 Initialize(0,0.7746,0.63246,0,0,0,0,0) ├──┼───░────
#                │                                         │  │   ░
# change_rate_2: ┤2                                        ├──■───░────
#                └─────────────────────────────────────────┘┌─┴─┐ ░ ┌─┐
#    very_small: ───────────────────────────────────────────┤ X ├─░─┤M├
#                                                           └───┘ ░ └╥┘
#          c8: 1/════════════════════════════════════════════════════╩═
#                                                                    0
# transpiled depth qc small 4
# Operations small OrderedDict([('initialize', 2), ('ccx', 2), ('barrier', 2), ('measure', 1)])
#                      ┌──────────────────────────────┐           ░       ░
#   env_light_0: ──────┤0                             ├───────────░───────░────
#                      │                              │           ░       ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├───────■───░───────░────
#                      │                              │       │   ░       ░
#   env_light_2: ──────┤2                             ├───────┼───░───■───░────
#                ┌─────┴──────────────────────────────┴────┐  │   ░   │   ░
# change_rate_0: ┤0                                        ├──┼───░───┼───░────
#                │                                         │  │   ░   │   ░
# change_rate_1: ┤1 Initialize(0,0.7746,0.63246,0,0,0,0,0) ├──┼───░───■───░────
#                │                                         │  │   ░   │   ░
# change_rate_2: ┤2                                        ├──■───░───┼───░────
#                └─────────────────────────────────────────┘┌─┴─┐ ░ ┌─┴─┐ ░ ┌─┐
#         small: ───────────────────────────────────────────┤ X ├─░─┤ X ├─░─┤M├
#                                                           └───┘ ░ └───┘ ░ └╥┘
#          c9: 1/════════════════════════════════════════════════════════════╩═
#                                                                            0
# transpiled depth qc big 9
# Operations big OrderedDict([('x', 4), ('ccx', 3), ('barrier', 3), ('initialize', 2), ('measure', 1)])
#                      ┌──────────────────────────────┐                     ░ »
#   env_light_0: ──────┤0                             ├────────────■────────░─»
#                      │                              │            │        ░ »
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────────┼────────░─»
#                      │                              │            │        ░ »
#   env_light_2: ──────┤2                             ├────────────┼────────░─»
#                ┌─────┴──────────────────────────────┴────┐┌───┐  │  ┌───┐ ░ »
# change_rate_0: ┤0                                        ├┤ X ├──■──┤ X ├─░─»
#                │                                         │└───┘  │  └───┘ ░ »
# change_rate_1: ┤1 Initialize(0,0.7746,0.63246,0,0,0,0,0) ├───────┼────────░─»
#                │                                         │       │        ░ »
# change_rate_2: ┤2                                        ├───────┼────────░─»
#                └─────────────────────────────────────────┘     ┌─┴─┐      ░ »
#           big: ────────────────────────────────────────────────┤ X ├──────░─»
#                                                                └───┘      ░ »
#         c10: 1/═════════════════════════════════════════════════════════════»
#                                                                             »
# «                               ░       ░
# «  env_light_0: ────────────────░───────░────
# «                               ░       ░
# «  env_light_1: ───────■────────░───────░────
# «                      │        ░       ░
# «  env_light_2: ───────┼────────░───■───░────
# «                      │        ░   │   ░
# «change_rate_0: ───────┼────────░───■───░────
# «                      │        ░   │   ░
# «change_rate_1: ───────┼────────░───┼───░────
# «               ┌───┐  │  ┌───┐ ░   │   ░
# «change_rate_2: ┤ X ├──■──┤ X ├─░───┼───░────
# «               └───┘┌─┴─┐└───┘ ░ ┌─┴─┐ ░ ┌─┐
# «          big: ─────┤ X ├──────░─┤ X ├─░─┤M├
# «                    └───┘      ░ └───┘ ░ └╥┘
# «        c10: 1/═══════════════════════════╩═
# «                                          0
# transpiled depth qc very_big 3
# Operations very_big OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                      ┌──────────────────────────────┐           ░
#   env_light_0: ──────┤0                             ├───────■───░────
#                      │                              │       │   ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├───────┼───░────
#                      │                              │       │   ░
#   env_light_2: ──────┤2                             ├───────┼───░────
#                ┌─────┴──────────────────────────────┴────┐  │   ░
# change_rate_0: ┤0                                        ├──■───░────
#                │                                         │  │   ░
# change_rate_1: ┤1 Initialize(0,0.7746,0.63246,0,0,0,0,0) ├──┼───░────
#                │                                         │  │   ░
# change_rate_2: ┤2                                        ├──┼───░────
#                └─────────────────────────────────────────┘┌─┴─┐ ░ ┌─┐
#      very_big: ───────────────────────────────────────────┤ X ├─░─┤M├
#                                                           └───┘ ░ └╥┘
#         c11: 1/════════════════════════════════════════════════════╩═
#                                                                    0
# transpiled depth qc very_small 3
# Operations very_small OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                      ┌──────────────────────────────┐           ░
#   env_light_0: ──────┤0                             ├───────────░────
#                      │                              │           ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├───────────░────
#                      │                              │           ░
#   env_light_2: ──────┤2                             ├───────■───░────
#                ┌─────┴──────────────────────────────┴────┐  │   ░
# change_rate_0: ┤0                                        ├──┼───░────
#                │                                         │  │   ░
# change_rate_1: ┤1 Initialize(0,0.63246,0.7746,0,0,0,0,0) ├──┼───░────
#                │                                         │  │   ░
# change_rate_2: ┤2                                        ├──■───░────
#                └─────────────────────────────────────────┘┌─┴─┐ ░ ┌─┐
#    very_small: ───────────────────────────────────────────┤ X ├─░─┤M├
#                                                           └───┘ ░ └╥┘
#         c12: 1/════════════════════════════════════════════════════╩═
#                                                                    0
# transpiled depth qc small 4
# Operations small OrderedDict([('initialize', 2), ('ccx', 2), ('barrier', 2), ('measure', 1)])
#                      ┌──────────────────────────────┐           ░       ░
#   env_light_0: ──────┤0                             ├───────────░───────░────
#                      │                              │           ░       ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├───────■───░───────░────
#                      │                              │       │   ░       ░
#   env_light_2: ──────┤2                             ├───────┼───░───■───░────
#                ┌─────┴──────────────────────────────┴────┐  │   ░   │   ░
# change_rate_0: ┤0                                        ├──┼───░───┼───░────
#                │                                         │  │   ░   │   ░
# change_rate_1: ┤1 Initialize(0,0.63246,0.7746,0,0,0,0,0) ├──┼───░───■───░────
#                │                                         │  │   ░   │   ░
# change_rate_2: ┤2                                        ├──■───░───┼───░────
#                └─────────────────────────────────────────┘┌─┴─┐ ░ ┌─┴─┐ ░ ┌─┐
#         small: ───────────────────────────────────────────┤ X ├─░─┤ X ├─░─┤M├
#                                                           └───┘ ░ └───┘ ░ └╥┘
#         c13: 1/════════════════════════════════════════════════════════════╩═
#                                                                            0
# transpiled depth qc big 9
# Operations big OrderedDict([('x', 4), ('ccx', 3), ('barrier', 3), ('initialize', 2), ('measure', 1)])
#                      ┌──────────────────────────────┐                     ░ »
#   env_light_0: ──────┤0                             ├────────────■────────░─»
#                      │                              │            │        ░ »
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────────┼────────░─»
#                      │                              │            │        ░ »
#   env_light_2: ──────┤2                             ├────────────┼────────░─»
#                ┌─────┴──────────────────────────────┴────┐┌───┐  │  ┌───┐ ░ »
# change_rate_0: ┤0                                        ├┤ X ├──■──┤ X ├─░─»
#                │                                         │└───┘  │  └───┘ ░ »
# change_rate_1: ┤1 Initialize(0,0.63246,0.7746,0,0,0,0,0) ├───────┼────────░─»
#                │                                         │       │        ░ »
# change_rate_2: ┤2                                        ├───────┼────────░─»
#                └─────────────────────────────────────────┘     ┌─┴─┐      ░ »
#           big: ────────────────────────────────────────────────┤ X ├──────░─»
#                                                                └───┘      ░ »
#         c14: 1/═════════════════════════════════════════════════════════════»
#                                                                             »
# «                               ░       ░
# «  env_light_0: ────────────────░───────░────
# «                               ░       ░
# «  env_light_1: ───────■────────░───────░────
# «                      │        ░       ░
# «  env_light_2: ───────┼────────░───■───░────
# «                      │        ░   │   ░
# «change_rate_0: ───────┼────────░───■───░────
# «                      │        ░   │   ░
# «change_rate_1: ───────┼────────░───┼───░────
# «               ┌───┐  │  ┌───┐ ░   │   ░
# «change_rate_2: ┤ X ├──■──┤ X ├─░───┼───░────
# «               └───┘┌─┴─┐└───┘ ░ ┌─┴─┐ ░ ┌─┐
# «          big: ─────┤ X ├──────░─┤ X ├─░─┤M├
# «                    └───┘      ░ └───┘ ░ └╥┘
# «        c14: 1/═══════════════════════════╩═
# «                                          0
# transpiled depth qc very_big 3
# Operations very_big OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                      ┌──────────────────────────────┐           ░
#   env_light_0: ──────┤0                             ├───────■───░────
#                      │                              │       │   ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├───────┼───░────
#                      │                              │       │   ░
#   env_light_2: ──────┤2                             ├───────┼───░────
#                ┌─────┴──────────────────────────────┴────┐  │   ░
# change_rate_0: ┤0                                        ├──■───░────
#                │                                         │  │   ░
# change_rate_1: ┤1 Initialize(0,0.63246,0.7746,0,0,0,0,0) ├──┼───░────
#                │                                         │  │   ░
# change_rate_2: ┤2                                        ├──┼───░────
#                └─────────────────────────────────────────┘┌─┴─┐ ░ ┌─┐
#      very_big: ───────────────────────────────────────────┤ X ├─░─┤M├
#                                                           └───┘ ░ └╥┘
#         c15: 1/════════════════════════════════════════════════════╩═
#                                                                    0
# transpiled depth qc very_small 3
# Operations very_small OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                      ┌──────────────────────────────┐            ░
#   env_light_0: ──────┤0                             ├────────────░────
#                      │                              │            ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────────░────
#                      │                              │            ░
#   env_light_2: ──────┤2                             ├────────■───░────
#                ┌─────┴──────────────────────────────┴─────┐  │   ░
# change_rate_0: ┤0                                         ├──┼───░────
#                │                                          │  │   ░
# change_rate_1: ┤1 Initialize(0,0.44721,0.89443,0,0,0,0,0) ├──┼───░────
#                │                                          │  │   ░
# change_rate_2: ┤2                                         ├──■───░────
#                └──────────────────────────────────────────┘┌─┴─┐ ░ ┌─┐
#    very_small: ────────────────────────────────────────────┤ X ├─░─┤M├
#                                                            └───┘ ░ └╥┘
#         c16: 1/═════════════════════════════════════════════════════╩═
#                                                                     0
# transpiled depth qc small 4
# Operations small OrderedDict([('initialize', 2), ('ccx', 2), ('barrier', 2), ('measure', 1)])
#                      ┌──────────────────────────────┐            ░       ░
#   env_light_0: ──────┤0                             ├────────────░───────░────
#                      │                              │            ░       ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────■───░───────░────
#                      │                              │        │   ░       ░
#   env_light_2: ──────┤2                             ├────────┼───░───■───░────
#                ┌─────┴──────────────────────────────┴─────┐  │   ░   │   ░
# change_rate_0: ┤0                                         ├──┼───░───┼───░────
#                │                                          │  │   ░   │   ░
# change_rate_1: ┤1 Initialize(0,0.44721,0.89443,0,0,0,0,0) ├──┼───░───■───░────
#                │                                          │  │   ░   │   ░
# change_rate_2: ┤2                                         ├──■───░───┼───░────
#                └──────────────────────────────────────────┘┌─┴─┐ ░ ┌─┴─┐ ░ ┌─┐
#         small: ────────────────────────────────────────────┤ X ├─░─┤ X ├─░─┤M├
#                                                            └───┘ ░ └───┘ ░ └╥┘
#         c17: 1/═════════════════════════════════════════════════════════════╩═
#                                                                             0
# transpiled depth qc big 9
# Operations big OrderedDict([('x', 4), ('ccx', 3), ('barrier', 3), ('initialize', 2), ('measure', 1)])
#                      ┌──────────────────────────────┐                      ░ »
#   env_light_0: ──────┤0                             ├─────────────■────────░─»
#                      │                              │             │        ░ »
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├─────────────┼────────░─»
#                      │                              │             │        ░ »
#   env_light_2: ──────┤2                             ├─────────────┼────────░─»
#                ┌─────┴──────────────────────────────┴─────┐┌───┐  │  ┌───┐ ░ »
# change_rate_0: ┤0                                         ├┤ X ├──■──┤ X ├─░─»
#                │                                          │└───┘  │  └───┘ ░ »
# change_rate_1: ┤1 Initialize(0,0.44721,0.89443,0,0,0,0,0) ├───────┼────────░─»
#                │                                          │       │        ░ »
# change_rate_2: ┤2                                         ├───────┼────────░─»
#                └──────────────────────────────────────────┘     ┌─┴─┐      ░ »
#           big: ─────────────────────────────────────────────────┤ X ├──────░─»
#                                                                 └───┘      ░ »
#         c18: 1/══════════════════════════════════════════════════════════════»
#                                                                              »
# «                               ░       ░
# «  env_light_0: ────────────────░───────░────
# «                               ░       ░
# «  env_light_1: ───────■────────░───────░────
# «                      │        ░       ░
# «  env_light_2: ───────┼────────░───■───░────
# «                      │        ░   │   ░
# «change_rate_0: ───────┼────────░───■───░────
# «                      │        ░   │   ░
# «change_rate_1: ───────┼────────░───┼───░────
# «               ┌───┐  │  ┌───┐ ░   │   ░
# «change_rate_2: ┤ X ├──■──┤ X ├─░───┼───░────
# «               └───┘┌─┴─┐└───┘ ░ ┌─┴─┐ ░ ┌─┐
# «          big: ─────┤ X ├──────░─┤ X ├─░─┤M├
# «                    └───┘      ░ └───┘ ░ └╥┘
# «        c18: 1/═══════════════════════════╩═
# «                                          0
# transpiled depth qc very_big 3
# Operations very_big OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                      ┌──────────────────────────────┐            ░
#   env_light_0: ──────┤0                             ├────────■───░────
#                      │                              │        │   ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────┼───░────
#                      │                              │        │   ░
#   env_light_2: ──────┤2                             ├────────┼───░────
#                ┌─────┴──────────────────────────────┴─────┐  │   ░
# change_rate_0: ┤0                                         ├──■───░────
#                │                                          │  │   ░
# change_rate_1: ┤1 Initialize(0,0.44721,0.89443,0,0,0,0,0) ├──┼───░────
#                │                                          │  │   ░
# change_rate_2: ┤2                                         ├──┼───░────
#                └──────────────────────────────────────────┘┌─┴─┐ ░ ┌─┐
#      very_big: ────────────────────────────────────────────┤ X ├─░─┤M├
#                                                            └───┘ ░ └╥┘
#         c19: 1/═════════════════════════════════════════════════════╩═
#                                                                     0
# transpiled depth qc very_small 3
# Operations very_small OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                               ┌──────────────────────────────┐              »
#   env_light_0: ───────────────┤0                             ├──────────────»
#                               │                              │              »
#   env_light_1: ───────────────┤1 Initialize(0,1,0,0,0,0,0,0) ├──────────────»
#                               │                              │              »
#   env_light_2: ───────────────┤2                             ├──────────────»
#                ┌──────────────┴──────────────────────────────┴─────────────┐»
# change_rate_0: ┤0                                                          ├»
#                │                                                           │»
# change_rate_1: ┤1 Initialize(1.0537e-08,0.050125,0.99748,0,0.050125,0,0,0) ├»
#                │                                                           │»
# change_rate_2: ┤2                                                          ├»
#                └───────────────────────────────────────────────────────────┘»
#    very_small: ─────────────────────────────────────────────────────────────»
#                                                                             »
#         c20: 1/═════════════════════════════════════════════════════════════»
#                                                                             »
# «                     ░
# «  env_light_0: ──────░────
# «                     ░
# «  env_light_1: ──────░────
# «                     ░
# «  env_light_2: ──■───░────
# «                 │   ░
# «change_rate_0: ──┼───░────
# «                 │   ░
# «change_rate_1: ──┼───░────
# «                 │   ░
# «change_rate_2: ──■───░────
# «               ┌─┴─┐ ░ ┌─┐
# «   very_small: ┤ X ├─░─┤M├
# «               └───┘ ░ └╥┘
# «        c20: 1/═════════╩═
# «                        0
# transpiled depth qc small 4
# Operations small OrderedDict([('initialize', 2), ('ccx', 2), ('barrier', 2), ('measure', 1)])
#                               ┌──────────────────────────────┐              »
#   env_light_0: ───────────────┤0                             ├──────────────»
#                               │                              │              »
#   env_light_1: ───────────────┤1 Initialize(0,1,0,0,0,0,0,0) ├──────────────»
#                               │                              │              »
#   env_light_2: ───────────────┤2                             ├──────────────»
#                ┌──────────────┴──────────────────────────────┴─────────────┐»
# change_rate_0: ┤0                                                          ├»
#                │                                                           │»
# change_rate_1: ┤1 Initialize(1.0537e-08,0.050125,0.99748,0,0.050125,0,0,0) ├»
#                │                                                           │»
# change_rate_2: ┤2                                                          ├»
#                └───────────────────────────────────────────────────────────┘»
#         small: ─────────────────────────────────────────────────────────────»
#                                                                             »
#         c21: 1/═════════════════════════════════════════════════════════════»
#                                                                             »
# «                     ░       ░
# «  env_light_0: ──────░───────░────
# «                     ░       ░
# «  env_light_1: ──■───░───────░────
# «                 │   ░       ░
# «  env_light_2: ──┼───░───■───░────
# «                 │   ░   │   ░
# «change_rate_0: ──┼───░───┼───░────
# «                 │   ░   │   ░
# «change_rate_1: ──┼───░───■───░────
# «                 │   ░   │   ░
# «change_rate_2: ──■───░───┼───░────
# «               ┌─┴─┐ ░ ┌─┴─┐ ░ ┌─┐
# «        small: ┤ X ├─░─┤ X ├─░─┤M├
# «               └───┘ ░ └───┘ ░ └╥┘
# «        c21: 1/═════════════════╩═
# «                                0
# transpiled depth qc big 9
# Operations big OrderedDict([('x', 4), ('ccx', 3), ('barrier', 3), ('initialize', 2), ('measure', 1)])
#                               ┌──────────────────────────────┐              »
#   env_light_0: ───────────────┤0                             ├──────────────»
#                               │                              │              »
#   env_light_1: ───────────────┤1 Initialize(0,1,0,0,0,0,0,0) ├──────────────»
#                               │                              │              »
#   env_light_2: ───────────────┤2                             ├──────────────»
#                ┌──────────────┴──────────────────────────────┴─────────────┐»
# change_rate_0: ┤0                                                          ├»
#                │                                                           │»
# change_rate_1: ┤1 Initialize(1.0537e-08,0.050125,0.99748,0,0.050125,0,0,0) ├»
#                │                                                           │»
# change_rate_2: ┤2                                                          ├»
#                └───────────────────────────────────────────────────────────┘»
#           big: ─────────────────────────────────────────────────────────────»
#                                                                             »
#         c22: 1/═════════════════════════════════════════════════════════════»
#                                                                             »
# «                               ░                 ░       ░
# «  env_light_0: ───────■────────░─────────────────░───────░────
# «                      │        ░                 ░       ░
# «  env_light_1: ───────┼────────░────────■────────░───────░────
# «                      │        ░        │        ░       ░
# «  env_light_2: ───────┼────────░────────┼────────░───■───░────
# «               ┌───┐  │  ┌───┐ ░        │        ░   │   ░
# «change_rate_0: ┤ X ├──■──┤ X ├─░────────┼────────░───■───░────
# «               └───┘  │  └───┘ ░        │        ░   │   ░
# «change_rate_1: ───────┼────────░────────┼────────░───┼───░────
# «                      │        ░ ┌───┐  │  ┌───┐ ░   │   ░
# «change_rate_2: ───────┼────────░─┤ X ├──■──┤ X ├─░───┼───░────
# «                    ┌─┴─┐      ░ └───┘┌─┴─┐└───┘ ░ ┌─┴─┐ ░ ┌─┐
# «          big: ─────┤ X ├──────░──────┤ X ├──────░─┤ X ├─░─┤M├
# «                    └───┘      ░      └───┘      ░ └───┘ ░ └╥┘
# «        c22: 1/═════════════════════════════════════════════╩═
# «                                                            0
# transpiled depth qc very_big 3
# Operations very_big OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                               ┌──────────────────────────────┐              »
#   env_light_0: ───────────────┤0                             ├──────────────»
#                               │                              │              »
#   env_light_1: ───────────────┤1 Initialize(0,1,0,0,0,0,0,0) ├──────────────»
#                               │                              │              »
#   env_light_2: ───────────────┤2                             ├──────────────»
#                ┌──────────────┴──────────────────────────────┴─────────────┐»
# change_rate_0: ┤0                                                          ├»
#                │                                                           │»
# change_rate_1: ┤1 Initialize(1.0537e-08,0.050125,0.99748,0,0.050125,0,0,0) ├»
#                │                                                           │»
# change_rate_2: ┤2                                                          ├»
#                └───────────────────────────────────────────────────────────┘»
#      very_big: ─────────────────────────────────────────────────────────────»
#                                                                             »
#         c23: 1/═════════════════════════════════════════════════════════════»
#                                                                             »
# «                     ░
# «  env_light_0: ──■───░────
# «                 │   ░
# «  env_light_1: ──┼───░────
# «                 │   ░
# «  env_light_2: ──┼───░────
# «                 │   ░
# «change_rate_0: ──■───░────
# «                 │   ░
# «change_rate_1: ──┼───░────
# «                 │   ░
# «change_rate_2: ──┼───░────
# «               ┌─┴─┐ ░ ┌─┐
# «     very_big: ┤ X ├─░─┤M├
# «               └───┘ ░ └╥┘
# «        c23: 1/═════════╩═
# «                        0
# transpiled depth qc very_small 3
# Operations very_small OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                           ┌──────────────────────────────┐                ░
#   env_light_0: ───────────┤0                             ├────────────────░────
#                           │                              │                ░
#   env_light_1: ───────────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────────────░────
#                           │                              │                ░
#   env_light_2: ───────────┤2                             ├────────────■───░────
#                ┌──────────┴──────────────────────────────┴─────────┐  │   ░
# change_rate_0: ┤0                                                  ├──┼───░────
#                │                                                   │  │   ░
# change_rate_1: ┤1 Initialize(1.0537e-08,0,0.89443,0,0.44721,0,0,0) ├──┼───░────
#                │                                                   │  │   ░
# change_rate_2: ┤2                                                  ├──■───░────
#                └───────────────────────────────────────────────────┘┌─┴─┐ ░ ┌─┐
#    very_small: ─────────────────────────────────────────────────────┤ X ├─░─┤M├
#                                                                     └───┘ ░ └╥┘
#         c24: 1/══════════════════════════════════════════════════════════════╩═
#                                                                              0
# transpiled depth qc small 4
# Operations small OrderedDict([('initialize', 2), ('ccx', 2), ('barrier', 2), ('measure', 1)])
#                           ┌──────────────────────────────┐                ░ »
#   env_light_0: ───────────┤0                             ├────────────────░─»
#                           │                              │                ░ »
#   env_light_1: ───────────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────────■───░─»
#                           │                              │            │   ░ »
#   env_light_2: ───────────┤2                             ├────────────┼───░─»
#                ┌──────────┴──────────────────────────────┴─────────┐  │   ░ »
# change_rate_0: ┤0                                                  ├──┼───░─»
#                │                                                   │  │   ░ »
# change_rate_1: ┤1 Initialize(1.0537e-08,0,0.89443,0,0.44721,0,0,0) ├──┼───░─»
#                │                                                   │  │   ░ »
# change_rate_2: ┤2                                                  ├──■───░─»
#                └───────────────────────────────────────────────────┘┌─┴─┐ ░ »
#         small: ─────────────────────────────────────────────────────┤ X ├─░─»
#                                                                     └───┘ ░ »
#         c25: 1/═════════════════════════════════════════════════════════════»
#                                                                             »
# «                     ░
# «  env_light_0: ──────░────
# «                     ░
# «  env_light_1: ──────░────
# «                     ░
# «  env_light_2: ──■───░────
# «                 │   ░
# «change_rate_0: ──┼───░────
# «                 │   ░
# «change_rate_1: ──■───░────
# «                 │   ░
# «change_rate_2: ──┼───░────
# «               ┌─┴─┐ ░ ┌─┐
# «        small: ┤ X ├─░─┤M├
# «               └───┘ ░ └╥┘
# «        c25: 1/═════════╩═
# «                        0
# transpiled depth qc big 9
# Operations big OrderedDict([('x', 4), ('ccx', 3), ('barrier', 3), ('initialize', 2), ('measure', 1)])
#                           ┌──────────────────────────────┐                    »
#   env_light_0: ───────────┤0                             ├─────────────────■──»
#                           │                              │                 │  »
#   env_light_1: ───────────┤1 Initialize(0,1,0,0,0,0,0,0) ├─────────────────┼──»
#                           │                              │                 │  »
#   env_light_2: ───────────┤2                             ├─────────────────┼──»
#                ┌──────────┴──────────────────────────────┴─────────┐┌───┐  │  »
# change_rate_0: ┤0                                                  ├┤ X ├──■──»
#                │                                                   │└───┘  │  »
# change_rate_1: ┤1 Initialize(1.0537e-08,0,0.89443,0,0.44721,0,0,0) ├───────┼──»
#                │                                                   │       │  »
# change_rate_2: ┤2                                                  ├───────┼──»
#                └───────────────────────────────────────────────────┘     ┌─┴─┐»
#           big: ──────────────────────────────────────────────────────────┤ X ├»
#                                                                          └───┘»
#         c26: 1/═══════════════════════════════════════════════════════════════»
#                                                                               »
# «                     ░                 ░       ░
# «  env_light_0: ──────░─────────────────░───────░────
# «                     ░                 ░       ░
# «  env_light_1: ──────░────────■────────░───────░────
# «                     ░        │        ░       ░
# «  env_light_2: ──────░────────┼────────░───■───░────
# «               ┌───┐ ░        │        ░   │   ░
# «change_rate_0: ┤ X ├─░────────┼────────░───■───░────
# «               └───┘ ░        │        ░   │   ░
# «change_rate_1: ──────░────────┼────────░───┼───░────
# «                     ░ ┌───┐  │  ┌───┐ ░   │   ░
# «change_rate_2: ──────░─┤ X ├──■──┤ X ├─░───┼───░────
# «                     ░ └───┘┌─┴─┐└───┘ ░ ┌─┴─┐ ░ ┌─┐
# «          big: ──────░──────┤ X ├──────░─┤ X ├─░─┤M├
# «                     ░      └───┘      ░ └───┘ ░ └╥┘
# «        c26: 1/═══════════════════════════════════╩═
# «                                                  0
# transpiled depth qc very_big 3
# Operations very_big OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                           ┌──────────────────────────────┐                ░
#   env_light_0: ───────────┤0                             ├────────────■───░────
#                           │                              │            │   ░
#   env_light_1: ───────────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────────┼───░────
#                           │                              │            │   ░
#   env_light_2: ───────────┤2                             ├────────────┼───░────
#                ┌──────────┴──────────────────────────────┴─────────┐  │   ░
# change_rate_0: ┤0                                                  ├──■───░────
#                │                                                   │  │   ░
# change_rate_1: ┤1 Initialize(1.0537e-08,0,0.89443,0,0.44721,0,0,0) ├──┼───░────
#                │                                                   │  │   ░
# change_rate_2: ┤2                                                  ├──┼───░────
#                └───────────────────────────────────────────────────┘┌─┴─┐ ░ ┌─┐
#      very_big: ─────────────────────────────────────────────────────┤ X ├─░─┤M├
#                                                                     └───┘ ░ └╥┘
#         c27: 1/══════════════════════════════════════════════════════════════╩═
#                                                                              0
# transpiled depth qc very_small 3
# Operations very_small OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                      ┌──────────────────────────────┐           ░
#   env_light_0: ──────┤0                             ├───────────░────
#                      │                              │           ░
#   env_light_1: ──────┤1 Initialize(0,1,0,0,0,0,0,0) ├───────────░────
#                      │                              │           ░
#   env_light_2: ──────┤2                             ├───────■───░────
#                ┌─────┴──────────────────────────────┴────┐  │   ░
# change_rate_0: ┤0                                        ├──┼───░────
#                │                                         │  │   ░
# change_rate_1: ┤1 Initialize(0,0,0.7746,0,0.63246,0,0,0) ├──┼───░────
#                │                                         │  │   ░
# change_rate_2: ┤2                                        ├──■───░────
#                └─────────────────────────────────────────┘┌─┴─┐ ░ ┌─┐
#    very_small: ───────────────────────────────────────────┤ X ├─░─┤M├
#                                                           └───┘ ░ └╥┘
# ...
#                                                                 0
# transpiled depth qc big 9
# Operations big OrderedDict([('x', 4), ('ccx', 3), ('barrier', 3), ('initialize', 2), ('measure', 1)])
#                ┌──────────────────────────────┐                ░           »
#   env_light_0: ┤0                             ├───────■────────░───────────»
#                │                              │       │        ░           »
#   env_light_1: ┤1 Initialize(0,1,0,0,0,0,0,0) ├───────┼────────░────────■──»
#                │                              │       │        ░        │  »
#   env_light_2: ┤2                             ├───────┼────────░────────┼──»
#                ├──────────────────────────────┤┌───┐  │  ┌───┐ ░        │  »
# change_rate_0: ┤0                             ├┤ X ├──■──┤ X ├─░────────┼──»
#                │                              │└───┘  │  └───┘ ░        │  »
# change_rate_1: ┤1 Initialize(0,0,0,0,1,0,0,0) ├───────┼────────░────────┼──»
#                │                              │       │        ░ ┌───┐  │  »
# change_rate_2: ┤2                             ├───────┼────────░─┤ X ├──■──»
#                └──────────────────────────────┘     ┌─┴─┐      ░ └───┘┌─┴─┐»
#           big: ─────────────────────────────────────┤ X ├──────░──────┤ X ├»
#                                                     └───┘      ░      └───┘»
#         c42: 1/════════════════════════════════════════════════════════════»
#                                                                            »
# «                     ░       ░
# «  env_light_0: ──────░───────░────
# «                     ░       ░
# «  env_light_1: ──────░───────░────
# «                     ░       ░
# «  env_light_2: ──────░───■───░────
# «                     ░   │   ░
# «change_rate_0: ──────░───■───░────
# «                     ░   │   ░
# «change_rate_1: ──────░───┼───░────
# «               ┌───┐ ░   │   ░
# «change_rate_2: ┤ X ├─░───┼───░────
# «               └───┘ ░ ┌─┴─┐ ░ ┌─┐
# «          big: ──────░─┤ X ├─░─┤M├
# «                     ░ └───┘ ░ └╥┘
# «        c42: 1/═════════════════╩═
# «                                0
# transpiled depth qc very_big 3
# Operations very_big OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                ┌──────────────────────────────┐      ░
#   env_light_0: ┤0                             ├──■───░────
#                │                              │  │   ░
#   env_light_1: ┤1 Initialize(0,1,0,0,0,0,0,0) ├──┼───░────
#                │                              │  │   ░
#   env_light_2: ┤2                             ├──┼───░────
#                ├──────────────────────────────┤  │   ░
# change_rate_0: ┤0                             ├──■───░────
#                │                              │  │   ░
# change_rate_1: ┤1 Initialize(0,0,0,0,1,0,0,0) ├──┼───░────
#                │                              │  │   ░
# change_rate_2: ┤2                             ├──┼───░────
#                └──────────────────────────────┘┌─┴─┐ ░ ┌─┐
#      very_big: ────────────────────────────────┤ X ├─░─┤M├
#                                                └───┘ ░ └╥┘
#         c43: 1/═════════════════════════════════════════╩═
#                                                         0
# transpiled depth qc very_small 3
# Operations very_small OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                ┌───────────────────────────────────────────┐      ░
#   env_light_0: ┤0                                          ├──────░────
#                │                                           │      ░
#   env_light_1: ┤1 Initialize(0,0.99887,0.047553,0,0,0,0,0) ├──────░────
#                │                                           │      ░
#   env_light_2: ┤2                                          ├──■───░────
#                └──────┬──────────────────────────────┬─────┘  │   ░
# change_rate_0: ───────┤0                             ├────────┼───░────
#                       │                              │        │   ░
# change_rate_1: ───────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────┼───░────
#                       │                              │        │   ░
# change_rate_2: ───────┤2                             ├────────■───░────
#                       └──────────────────────────────┘      ┌─┴─┐ ░ ┌─┐
#    very_small: ─────────────────────────────────────────────┤ X ├─░─┤M├
#                                                             └───┘ ░ └╥┘
#         c44: 1/══════════════════════════════════════════════════════╩═
#                                                                      0
# transpiled depth qc small 4
# Operations small OrderedDict([('initialize', 2), ('ccx', 2), ('barrier', 2), ('measure', 1)])
#                ┌───────────────────────────────────────────┐      ░       ░
#   env_light_0: ┤0                                          ├──────░───────░────
#                │                                           │      ░       ░
#   env_light_1: ┤1 Initialize(0,0.99887,0.047553,0,0,0,0,0) ├──■───░───────░────
#                │                                           │  │   ░       ░
#   env_light_2: ┤2                                          ├──┼───░───■───░────
#                └──────┬──────────────────────────────┬─────┘  │   ░   │   ░
# change_rate_0: ───────┤0                             ├────────┼───░───┼───░────
#                       │                              │        │   ░   │   ░
# change_rate_1: ───────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────┼───░───■───░────
#                       │                              │        │   ░   │   ░
# change_rate_2: ───────┤2                             ├────────■───░───┼───░────
#                       └──────────────────────────────┘      ┌─┴─┐ ░ ┌─┴─┐ ░ ┌─┐
#         small: ─────────────────────────────────────────────┤ X ├─░─┤ X ├─░─┤M├
#                                                             └───┘ ░ └───┘ ░ └╥┘
#         c45: 1/══════════════════════════════════════════════════════════════╩═
#                                                                              0
# transpiled depth qc big 9
# Operations big OrderedDict([('x', 4), ('ccx', 3), ('barrier', 3), ('initialize', 2), ('measure', 1)])
#                ┌───────────────────────────────────────────┐                ░ »
#   env_light_0: ┤0                                          ├───────■────────░─»
#                │                                           │       │        ░ »
#   env_light_1: ┤1 Initialize(0,0.99887,0.047553,0,0,0,0,0) ├───────┼────────░─»
#                │                                           │       │        ░ »
#   env_light_2: ┤2                                          ├───────┼────────░─»
#                └──────┬──────────────────────────────┬─────┘┌───┐  │  ┌───┐ ░ »
# change_rate_0: ───────┤0                             ├──────┤ X ├──■──┤ X ├─░─»
#                       │                              │      └───┘  │  └───┘ ░ »
# change_rate_1: ───────┤1 Initialize(0,1,0,0,0,0,0,0) ├─────────────┼────────░─»
#                       │                              │             │        ░ »
# change_rate_2: ───────┤2                             ├─────────────┼────────░─»
#                       └──────────────────────────────┘           ┌─┴─┐      ░ »
#           big: ──────────────────────────────────────────────────┤ X ├──────░─»
#                                                                  └───┘      ░ »
#         c46: 1/═══════════════════════════════════════════════════════════════»
#                                                                               »
# «                               ░       ░
# «  env_light_0: ────────────────░───────░────
# «                               ░       ░
# «  env_light_1: ───────■────────░───────░────
# «                      │        ░       ░
# «  env_light_2: ───────┼────────░───■───░────
# «                      │        ░   │   ░
# «change_rate_0: ───────┼────────░───■───░────
# «                      │        ░   │   ░
# «change_rate_1: ───────┼────────░───┼───░────
# «               ┌───┐  │  ┌───┐ ░   │   ░
# «change_rate_2: ┤ X ├──■──┤ X ├─░───┼───░────
# «               └───┘┌─┴─┐└───┘ ░ ┌─┴─┐ ░ ┌─┐
# «          big: ─────┤ X ├──────░─┤ X ├─░─┤M├
# «                    └───┘      ░ └───┘ ░ └╥┘
# «        c46: 1/═══════════════════════════╩═
# «                                          0
# transpiled depth qc very_big 3
# Operations very_big OrderedDict([('initialize', 2), ('ccx', 1), ('barrier', 1), ('measure', 1)])
#                ┌───────────────────────────────────────────┐      ░
#   env_light_0: ┤0                                          ├──■───░────
#                │                                           │  │   ░
#   env_light_1: ┤1 Initialize(0,0.99887,0.047553,0,0,0,0,0) ├──┼───░────
#                │                                           │  │   ░
#   env_light_2: ┤2                                          ├──┼───░────
#                └──────┬──────────────────────────────┬─────┘  │   ░
# change_rate_0: ───────┤0                             ├────────■───░────
#                       │                              │        │   ░
# change_rate_1: ───────┤1 Initialize(0,1,0,0,0,0,0,0) ├────────┼───░────
#                       │                              │        │   ░
# change_rate_2: ───────┤2                             ├────────┼───░────
#                       └──────────────────────────────┘      ┌─┴─┐ ░ ┌─┐
#      very_big: ─────────────────────────────────────────────┤ X ├─░─┤M├
#                                                             └───┘ ░ └╥┘
#         c47: 1/══════════════════════════════════════════════════════╩═
#                                                                      0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       6 for cr in cr_list:
#       7     qfie_linear.build_inference_qc({'env_light':el, 'change_rate':cr}, draw_qc=False, distributed=True)
# ----> 8     f_quantum_linear.append(qfie_linear.execute(n_shots=5000,  transpile_info=True, plot_histo=False)[0])
#       9     #qfie_log.build_inference_qc({'env_light':el, 'change_rate':cr}, draw_qc=False)
#      10     #f_quantum_log.append(qfie_log.execute(n_shots=5000, transpile_info=True, plot_histo=False)[0])
#
# File ~/MyPackages/QFIE/src/QFIE/FuzzyEngines.py:409, in QuantumFuzzyEngine.execute(self, n_shots, plot_histo, GPU, **kwargs)
#     406 subcounts = {}
#     408 # Execute quantum circuits
# --> 409 counts_list = list(map(QFS.compute_qc, backends_list,
#     410                                                     list(self.qc.values()), list(self.qc.keys()),
#     411                                                     repeat(n_shots), repeat(self.verbose),
#     412                                                     repeat(transp_info), repeat(optimization_level)))
#     414 for count in counts_list:
#     415     subcounts.update(count)
#
# File ~/MyPackages/QFIE/src/QFIE/QFS.py:179, in compute_qc(backend, qc, qc_label, n_shots, verbose, transpilation_info, optimization_level)
#     175         except: backend_name = 'AerSimulator'
#     176     print('Running qc ' + qc_label + ' on ' + backend_name)
# --> 179 pm = generate_preset_pass_manager(backend=backend, optimization_level=optimization_level)
#     180 transpiled_qc = pm.run(qc)
#     181 if transpilation_info:
#
# File ~/anaconda3/envs/qfie_env/lib/python3.11/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/qfie_env/lib/python3.11/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
#     [... skipping similar frames: deprecate_arg.<locals>.decorator.<locals>.wrapper at line 184 (1 times)]
#
# File ~/anaconda3/envs/qfie_env/lib/python3.11/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/qfie_env/lib/python3.11/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py:333, in generate_preset_pass_manager(optimization_level, backend, target, basis_gates, inst_map, coupling_map, instruction_durations, backend_properties, timing_constraints, initial_layout, layout_method, routing_method, translation_method, scheduling_method, approximation_degree, seed_transpiler, unitary_synthesis_method, unitary_synthesis_plugin_config, hls_config, init_method, optimization_method, dt, qubits_initially_zero, _skip_target)
#     330 inst_map = _parse_inst_map(inst_map, backend)
#     331 # The basis gates parser will set _skip_target to True if a custom basis gate is found
#     332 # (known edge case).
# --> 333 basis_gates, name_mapping, _skip_target = _parse_basis_gates(
#     334     basis_gates, backend, inst_map, _skip_target
#     335 )
#     336 coupling_map = _parse_coupling_map(coupling_map, backend)
#     338 if target is None:
#
# File ~/anaconda3/envs/qfie_env/lib/python3.11/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py:496, in _parse_basis_gates(basis_gates, backend, inst_map, skip_target)
#     492     return list(instructions), name_mapping, skip_target
#     494 instructions = instructions or backend.operation_names
#     495 name_mapping.update(
# --> 496     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#     497 )
#     499 # Check for custom instructions before removing calibrations
#     500 for inst in instructions:
#
# File ~/anaconda3/envs/qfie_env/lib/python3.11/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py:496, in <dictcomp>(.0)
#     492     return list(instructions), name_mapping, skip_target
#     494 instructions = instructions or backend.operation_names
#     495 name_mapping.update(
# --> 496     {name: backend.target.operation_from_name(name) for name in backend.operation_names}
#     497 )
#     499 # Check for custom instructions before removing calibrations
#     500 for inst in instructions:
#
# File ~/anaconda3/envs/qfie_env/lib/python3.11/site-packages/qiskit_aer/backends/aerbackend.py:423, in AerBackend.target(self)
#     418         target.add_instruction(
#     419             instruction=qiskit_control_flow_mapping[inst_name],
#     420             name=inst_name,
#     421         )
#     422     else:
# --> 423         target.add_instruction(
#     424             instruction=inst_name_map[inst_name],
#     425             properties=prop_name_map.get(inst_name, None),
#     426             name=inst_name,
#     427         )
#     429 if self._coupling_map is not None:
#     430     target._coupling_graph = self._coupling_map.graph.copy()
#
# File ~/anaconda3/envs/qfie_env/lib/python3.11/site-packages/qiskit/transpiler/target.py:444, in Target.add_instruction(self, instruction, properties, name)
#     442 if instruction_name in self._gate_map:
#     443     raise AttributeError(f"Instruction {instruction_name} is already in the target")
# --> 444 super().add_instruction(instruction, instruction_name, properties)
#     445 self._gate_map[instruction_name] = properties
#     446 self._coupling_graph = None
#
# KeyboardInterrupt:

# %% [markdown]
# ___
#
# Then, the classical Mamdani system is implemented by using the python library Sci-kit Fuzzy. The following cells initializes the system as required from the library

# %%
from skfuzzy import control as ctrl

# %%
env_l = ctrl.Antecedent(env_light, 'env_light')
cng_r = ctrl.Antecedent(changing_rate , 'change_rate')
dim = ctrl.Consequent(dimmer_control, 'dimmer_ctrl')

env_l['dark'] = l_dark
env_l['medium'] = l_medium
env_l['light'] = l_light 

cng_r['neg_small'] = r_ns
cng_r['zero'] = r_zero
cng_r['pos_small'] = r_ps 

dim['very_small'] = dm_vs
dim['small'] = dm_s
dim['big'] = dm_b
dim['very_big'] = dm_vb


rule1 = ctrl.Rule(env_l['dark'] & cng_r['pos_small'], dim['big'])
rule2 = ctrl.Rule(env_l['dark'] & cng_r['zero'], dim['big'])
rule3 = ctrl.Rule(env_l['dark'] & cng_r['neg_small'], dim['very_big'])
rule4 = ctrl.Rule(env_l['medium'] & cng_r['pos_small'], dim['small'])
rule5 = ctrl.Rule(env_l['medium'] & cng_r['zero'], dim['big'])
rule6 = ctrl.Rule(env_l['medium'] & cng_r['neg_small'], dim['big'])
rule7 = ctrl.Rule(env_l['light'] & cng_r['pos_small'], dim['very_small'])
rule8 = ctrl.Rule(env_l['light'] & cng_r['zero'], dim['small'])
rule9 = ctrl.Rule(env_l['light'] & cng_r['neg_small'], dim['big'])

dim_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9])
dim_sys = ctrl.ControlSystemSimulation(dim_ctrl)

# %% [markdown]
# By running the following cell, the same combinations of inputs are passed to the classical control which computes the 121 output. All the output values are stored in a list.

# %%
f_classical = []
for el in el_list:
    for cr in cr_list:
        dim_sys.input['env_light']=el    
        dim_sys.input['change_rate']=cr

        dim_sys.compute()
        f_classical.append(dim_sys.output['dimmer_ctrl'])

# %% [markdown]
# At this point, both the QFIE and Classical system' control surfaces can be plotted. Firstly, the following cell shows the former surface.

# %%
from mpl_toolkits.mplot3d import Axes3D

X, Y, = el_list, cr_list
plotx,ploty, = np.meshgrid(np.linspace(np.min(X),np.max(X),11), np.linspace(np.min(Y),np.max(Y),11))
Z = np.zeros_like(plotx)
counter = 0 
for i in range(len(el_list)):
    for j in range(len(cr_list)):
        Z[i,j]=f_quantum_linear[counter]
        counter+=1
        
zfig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(plotx, ploty, Z, rstride=1, cstride=1, cmap='viridis',
                       linewidth=0.4, antialiased=True)
ax.set_xlabel('Environment Light')
ax.set_ylabel('Changing Rate')
ax.set_zlabel('Dimmer Control')
# Out:
# Text(0.5, 0, 'Dimmer Control')

# %% [markdown]
# Then, the classical surface is displayed by running the following cell.

# %%
X, Y, = el_list, cr_list
plotx,ploty, = np.meshgrid(np.linspace(np.min(X),np.max(X),11), np.linspace(np.min(Y),np.max(Y),11))
Z = np.zeros_like(plotx)
counter = 0 
for i in range(len(el_list)):
    for j in range(len(cr_list)):
        Z[i,j]=f_quantum_log[counter]
        counter+=1
        
zfig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(plotx, ploty, Z, rstride=1, cstride=1, cmap='viridis',
                       linewidth=0.4, antialiased=True)
ax.set_xlabel('Environment Light')
ax.set_ylabel('Changing Rate')
ax.set_zlabel('Dimmer Control')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 7
#       5 for i in range(len(el_list)):
#       6     for j in range(len(cr_list)):
# ----> 7         Z[i,j]=f_quantum_log[counter]
#       8         counter+=1
#      10 zfig = plt.figure()
#
# IndexError: list index out of range

# %%
X, Y, = el_list, cr_list
plotx,ploty, = np.meshgrid(np.linspace(np.min(X),np.max(X),11), np.linspace(np.min(Y),np.max(Y),11))
Z = np.zeros_like(plotx)
counter = 0 
for i in range(len(el_list)):
    for j in range(len(cr_list)):
        Z[i,j]=f_classical[counter]
        counter+=1
        
zfig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(plotx, ploty, Z, rstride=1, cstride=1, cmap='viridis',
                       linewidth=0.4, antialiased=True)
ax.set_xlabel('Environment Light')
ax.set_ylabel('Changing Rate')
ax.set_zlabel('Dimmer Control')
# Out:
# Text(0.5, 0, 'Dimmer Control')

# %% [markdown]
# The two surfaces show how QFIE is able to control in a very similar way to a classical Mamdani fuzzy control the lighting control system, despite the computational advantage in firing the fuzzy rules in a parallel way.
