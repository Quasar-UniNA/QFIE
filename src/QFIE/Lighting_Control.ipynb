# %% [markdown]
# # QFIE For Lighting Controller System
# This notebook aims to illustrate how QFIE can control efficiently a lighting system, in  which  the  control system dim the bulb light automatically according to the environmental Light. Two input variables are considered, namely the environment light and the  changing  rate of the environmental light. Finally, the control surface of the system will be obtained both using QFIE and the canonical Mamdani fuzzy system, which configuration is reported in the paper.
#
# Firstly, let us import the required libraries.

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
import FuzzyEngines as FE
# Out:
# end

# %% [markdown]
# The system is a MISO composed of two input variables and one output variable. In detail:
#
# Inputs:
#
# - Environment Light (env_light): three linguistic terms are considered: 'Dark', 'Medium', 'Light'
#
# - Changing Rate (change_rate): three lingiuistic terms are considered: 'Negative Small', 'Zero', 'Positive Small'
#
# Output:
#
# - Dimmer Control (dimmer_ctrl): four linguistic terms are considered: 'Very Small', 'Small', 'Big', 'Very Big'
#
#
# By running the following cell, the fuzzy sets used are graphically shown.

# %%
env_light = np.linspace(120, 220, 200)
changing_rate = np.linspace(-10, 10, 200)
dimmer_control = np.linspace(0, 10, 200)



l_dark = fuzz.trapmf(env_light, [120,120,130,150])
l_medium = fuzz.trapmf(env_light, [130,  150, 190,210])
l_light = fuzz.trapmf(env_light, [190,  210, 220, 220])

r_ns = fuzz.trimf(changing_rate, [-10,-10,0])
r_zero = fuzz.trimf(changing_rate, [-10,0,10])
r_ps = fuzz.trimf(changing_rate, [0,10,10])

dm_vs = fuzz.trapmf(dimmer_control, [0,0,2,4])
dm_s = fuzz.trimf(dimmer_control, [2,4,6])
dm_b = fuzz.trimf(dimmer_control, [4,6,8])
dm_vb = fuzz.trapmf(dimmer_control, [6,8,10,10])




# Visualize these universes and membership functions
fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(10, 12))


ax0.plot(env_light, l_dark, 'b', linewidth=1.5, label='dark')
ax0.plot(env_light, l_medium, 'g', linewidth=1.5, label='medium')
ax0.plot(env_light, l_light, 'r', linewidth=1.5, label='light')
ax0.set_title('Environment Light')
ax0.legend()

ax1.plot(changing_rate, r_ns, 'b', linewidth=1.5, label='negative small')
ax1.plot(changing_rate, r_zero, 'g', linewidth=1.5, label='zero')
ax1.plot(changing_rate, r_ps, 'r', linewidth=1.5, label='positive small')
ax1.set_title('Changing Rate')
ax1.legend()


ax2.plot(dimmer_control, dm_vs, 'b', linewidth=1.5, label='very small')
ax2.plot(dimmer_control, dm_s, 'g', linewidth=1.5, label='small')
ax2.plot(dimmer_control, dm_b, 'r', linewidth=1.5, label='big')
ax2.plot(dimmer_control, dm_vb, 'y', linewidth=1.5, label='very big')
ax2.set_title('Dimmer control')
ax2.legend()

# Turn off top/right axes
for ax in (ax0, ax1, ax2):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()


plt.show()

# %% [markdown]
# The rules base of the system is composed of the following rules:
#
# - if env_light is dark and change_rate is pos_small then dimmer_ctrl is big
# - if env_light is dark and change_rate is zero then dimmer_ctrl is big
# - if env_light is dark and change_rate is neg_small then dimmer_ctrl is very_big
# - if env_light is medium and change_rate is pos_small then dimmer_ctrl is small
# - if env_light is medium and change_rate is zero then dimmer_ctrl is big
# - if env_light is medium and change_rate is neg_small then dimmer_ctrl is big
# - if env_light is light and change_rate is pos_small then dimmer_ctrl is very_small
# - if env_light is light and change_rate is zero then dimmer_ctrl is small
# - if env_light is light and change_rate is neg_small then dimmer_ctrl is big
#
# By running the following two cells QFIE is properly initialized

# %%
rules = ['if env_light is dark and change_rate is pos_small then dimmer_ctrl is big',
         'if env_light is dark and change_rate is zero then dimmer_ctrl is big',
         'if env_light is dark and change_rate is neg_small then dimmer_ctrl is very_big',
         'if env_light is medium and change_rate is pos_small then dimmer_ctrl is small',
         'if env_light is medium and change_rate is zero then dimmer_ctrl is big',
         'if env_light is medium and change_rate is neg_small then dimmer_ctrl is big',
         'if env_light is light and change_rate is pos_small then dimmer_ctrl is very_small',
         'if env_light is light and change_rate is zero then dimmer_ctrl is small',
         'if env_light is light and change_rate is neg_small then dimmer_ctrl is big']

# %%
qfie_linear = FE.QuantumFuzzyEngine(verbose=False, encoding='linear')
qfie_linear.input_variable(name='env_light', range=env_light)
qfie_linear.input_variable(name='change_rate', range=changing_rate)
qfie_linear.output_variable(name='dimmer_ctrl', range=dimmer_control)

qfie_linear.add_input_fuzzysets(var_name='env_light', set_names=['dark', 'medium', 'light'], sets=[l_dark, l_medium, l_light])
qfie_linear.add_input_fuzzysets(var_name='change_rate', set_names=['neg_small', 'zero', 'pos_small'], sets=[r_ns, r_zero, r_ps])
qfie_linear.add_output_fuzzysets(var_name='dimmer_ctrl', set_names=['very_small', 'small', 'big', 'very_big'],sets=[dm_vs, dm_s, dm_b, dm_vb])
qfie_linear.set_rules(rules)

qfie_log = FE.QuantumFuzzyEngine(verbose=False, encoding='logaritmic')
qfie_log.input_variable(name='env_light', range=env_light)
qfie_log.input_variable(name='change_rate', range=changing_rate)
qfie_log.output_variable(name='dimmer_ctrl', range=dimmer_control)

qfie_log.add_input_fuzzysets(var_name='env_light', set_names=['dark', 'medium', 'light'], sets=[l_dark, l_medium, l_light])
qfie_log.add_input_fuzzysets(var_name='change_rate', set_names=['neg_small', 'zero', 'pos_small'], sets=[r_ns, r_zero, r_ps])
qfie_log.add_output_fuzzysets(var_name='dimmer_ctrl', set_names=['very_small', 'small', 'big', 'very_big'],sets=[dm_vs, dm_s, dm_b, dm_vb])
qfie_log.set_rules(rules)

# %% [markdown]
# To obtain the control surface of QFIE, it is used to fire the rules in 121 different input combinations. In detail, for 11 values of env_light 11 different values of change_rate are considered. The 121 outputs obtained are collected in a list which will be used at the end of the notebook to plot the control surface.

# %%
from qiskit_ibm_runtime.fake_provider import FakeMumbaiV2

el_list, cr_list = [t for t in range(120, 230, 10)], [s for s in range(-10, 12, 2)]
f_quantum_linear, f_quantum_log = [], []
for el in el_list:
    for cr in cr_list:
        qfie_linear.build_inference_qc({'env_light':el, 'change_rate':cr}, draw_qc=False)
        f_quantum_linear.append(qfie_linear.execute(n_shots=5000, backend=FakeMumbaiV2(), transpile_info=True, plot_histo=False)[0])
        qfie_log.build_inference_qc({'env_light':el, 'change_rate':cr}, draw_qc=False)
        f_quantum_log.append(qfie_log.execute(n_shots=5000, backend=FakeMumbaiV2(), transpile_info=True, plot_histo=False)[0])
# Out:
# debug 3
# transpiled depth qc full_circuit 211
# Operations full_circuit OrderedDict([('rz', 133), ('cx', 113), ('sx', 61), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 784
# Operations full_circuit OrderedDict([('rz', 412), ('cx', 393), ('sx', 175), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 208
# Operations full_circuit OrderedDict([('rz', 133), ('cx', 116), ('sx', 64), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 2)])
# debug 3
# transpiled depth qc full_circuit 783
# Operations full_circuit OrderedDict([('rz', 419), ('cx', 389), ('sx', 183), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 210
# Operations full_circuit OrderedDict([('rz', 136), ('cx', 114), ('sx', 68), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 770
# Operations full_circuit OrderedDict([('rz', 458), ('cx', 383), ('sx', 219), ('x', 50), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 210
# Operations full_circuit OrderedDict([('rz', 136), ('cx', 114), ('sx', 68), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 783
# Operations full_circuit OrderedDict([('rz', 419), ('cx', 389), ('sx', 183), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 209
# Operations full_circuit OrderedDict([('rz', 133), ('cx', 116), ('sx', 64), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 2)])
# debug 3
# transpiled depth qc full_circuit 798
# Operations full_circuit OrderedDict([('rz', 421), ('cx', 395), ('sx', 184), ('x', 57), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 218
# Operations full_circuit OrderedDict([('rz', 140), ('cx', 114), ('sx', 71), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 782
# Operations full_circuit OrderedDict([('rz', 417), ('cx', 391), ('sx', 181), ('x', 59), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 206
# Operations full_circuit OrderedDict([('rz', 120), ('cx', 106), ('sx', 54), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 792
# Operations full_circuit OrderedDict([('rz', 420), ('cx', 398), ('sx', 181), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 205
# Operations full_circuit OrderedDict([('rz', 118), ('cx', 105), ('sx', 49), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 790
# Operations full_circuit OrderedDict([('rz', 433), ('cx', 410), ('sx', 192), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 204
# Operations full_circuit OrderedDict([('rz', 122), ('cx', 103), ('sx', 53), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 783
# Operations full_circuit OrderedDict([('rz', 419), ('cx', 389), ('sx', 181), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 204
# Operations full_circuit OrderedDict([('rz', 122), ('cx', 106), ('sx', 53), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 783
# Operations full_circuit OrderedDict([('rz', 419), ('cx', 389), ('sx', 181), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 204
# Operations full_circuit OrderedDict([('rz', 121), ('cx', 102), ('sx', 51), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 789
# Operations full_circuit OrderedDict([('rz', 427), ('cx', 411), ('sx', 186), ('x', 55), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 221
# Operations full_circuit OrderedDict([('rz', 136), ('cx', 117), ('sx', 65), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 788
# Operations full_circuit OrderedDict([('rz', 415), ('cx', 391), ('sx', 179), ('x', 59), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 220
# Operations full_circuit OrderedDict([('rz', 138), ('cx', 120), ('sx', 69), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 784
# Operations full_circuit OrderedDict([('rz', 469), ('cx', 380), ('sx', 231), ('x', 51), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 214
# Operations full_circuit OrderedDict([('rz', 140), ('cx', 118), ('sx', 72), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 775
# Operations full_circuit OrderedDict([('rz', 464), ('cx', 380), ('sx', 231), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 219
# Operations full_circuit OrderedDict([('rz', 140), ('cx', 121), ('sx', 71), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 772
# Operations full_circuit OrderedDict([('rz', 432), ('cx', 397), ('sx', 189), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 213
# Operations full_circuit OrderedDict([('rz', 137), ('cx', 120), ('sx', 68), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 2)])
# debug 3
# transpiled depth qc full_circuit 788
# Operations full_circuit OrderedDict([('rz', 479), ('cx', 376), ('sx', 239), ('x', 49), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 213
# Operations full_circuit OrderedDict([('rz', 139), ('cx', 120), ('sx', 70), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 2)])
# debug 3
# transpiled depth qc full_circuit 779
# Operations full_circuit OrderedDict([('rz', 471), ('cx', 380), ('sx', 233), ('x', 50), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 213
# Operations full_circuit OrderedDict([('rz', 128), ('cx', 110), ('sx', 56), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 773
# Operations full_circuit OrderedDict([('rz', 452), ('cx', 388), ('sx', 213), ('x', 49), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 213
# Operations full_circuit OrderedDict([('rz', 123), ('cx', 110), ('sx', 53), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 772
# Operations full_circuit OrderedDict([('rz', 453), ('cx', 386), ('sx', 217), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 210
# Operations full_circuit OrderedDict([('rz', 122), ('cx', 112), ('sx', 53), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 787
# Operations full_circuit OrderedDict([('rz', 479), ('cx', 376), ('sx', 237), ('x', 51), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 210
# Operations full_circuit OrderedDict([('rz', 120), ('cx', 112), ('sx', 51), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 804
# Operations full_circuit OrderedDict([('rz', 427), ('cx', 396), ('sx', 186), ('x', 59), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 214
# Operations full_circuit OrderedDict([('rz', 125), ('cx', 107), ('sx', 55), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 788
# Operations full_circuit OrderedDict([('rz', 416), ('cx', 391), ('sx', 179), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 212
# Operations full_circuit OrderedDict([('rz', 136), ('cx', 117), ('sx', 67), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 788
# Operations full_circuit OrderedDict([('rz', 415), ('cx', 391), ('sx', 179), ('x', 59), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 203
# Operations full_circuit OrderedDict([('rz', 140), ('cx', 121), ('sx', 68), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 794
# Operations full_circuit OrderedDict([('rz', 493), ('cx', 368), ('sx', 255), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 228
# Operations full_circuit OrderedDict([('rz', 146), ('cx', 116), ('sx', 71), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 789
# Operations full_circuit OrderedDict([('rz', 414), ('cx', 397), ('sx', 179), ('x', 57), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 228
# Operations full_circuit OrderedDict([('rz', 142), ('cx', 118), ('sx', 70), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 772
# Operations full_circuit OrderedDict([('rz', 428), ('cx', 399), ('sx', 185), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 211
# Operations full_circuit OrderedDict([('rz', 139), ('cx', 121), ('sx', 71), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 776
# Operations full_circuit OrderedDict([('rz', 459), ('cx', 384), ('sx', 223), ('x', 49), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 219
# Operations full_circuit OrderedDict([('rz', 144), ('cx', 118), ('sx', 75), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 788
# Operations full_circuit OrderedDict([('rz', 420), ('cx', 392), ('sx', 185), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 211
# Operations full_circuit OrderedDict([('rz', 124), ('cx', 110), ('sx', 58), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 788
# Operations full_circuit OrderedDict([('rz', 418), ('cx', 392), ('sx', 181), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 209
# Operations full_circuit OrderedDict([('rz', 126), ('cx', 110), ('sx', 57), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 768
# Operations full_circuit OrderedDict([('rz', 450), ('cx', 388), ('sx', 213), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 210
# Operations full_circuit OrderedDict([('rz', 122), ('cx', 109), ('sx', 53), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 775
# Operations full_circuit OrderedDict([('rz', 459), ('cx', 382), ('sx', 225), ('x', 55), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 203
# Operations full_circuit OrderedDict([('rz', 120), ('cx', 115), ('sx', 51), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 788
# Operations full_circuit OrderedDict([('rz', 418), ('cx', 392), ('sx', 181), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 203
# Operations full_circuit OrderedDict([('rz', 119), ('cx', 111), ('sx', 49), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 782
# Operations full_circuit OrderedDict([('rz', 466), ('cx', 379), ('sx', 227), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 212
# Operations full_circuit OrderedDict([('rz', 136), ('cx', 117), ('sx', 67), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 792
# Operations full_circuit OrderedDict([('rz', 411), ('cx', 396), ('sx', 175), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 213
# Operations full_circuit OrderedDict([('rz', 136), ('cx', 123), ('sx', 67), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 784
# Operations full_circuit OrderedDict([('rz', 468), ('cx', 380), ('sx', 231), ('x', 51), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 225
# Operations full_circuit OrderedDict([('rz', 136), ('cx', 123), ('sx', 69), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 770
# Operations full_circuit OrderedDict([('rz', 429), ('cx', 403), ('sx', 190), ('x', 53), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 213
# Operations full_circuit OrderedDict([('rz', 136), ('cx', 123), ('sx', 67), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 795
# Operations full_circuit OrderedDict([('rz', 432), ('cx', 413), ('sx', 194), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 220
# Operations full_circuit OrderedDict([('rz', 136), ('cx', 123), ('sx', 67), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 772
# Operations full_circuit OrderedDict([('rz', 428), ('cx', 399), ('sx', 185), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 217
# Operations full_circuit OrderedDict([('rz', 146), ('cx', 116), ('sx', 75), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 795
# Operations full_circuit OrderedDict([('rz', 438), ('cx', 411), ('sx', 200), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 210
# Operations full_circuit OrderedDict([('rz', 124), ('cx', 109), ('sx', 55), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 788
# Operations full_circuit OrderedDict([('rz', 418), ('cx', 392), ('sx', 181), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 213
# Operations full_circuit OrderedDict([('rz', 126), ('cx', 107), ('sx', 54), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 795
# Operations full_circuit OrderedDict([('rz', 436), ('cx', 411), ('sx', 196), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 193
# Operations full_circuit OrderedDict([('cx', 117), ('rz', 116), ('sx', 46), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 788
# Operations full_circuit OrderedDict([('rz', 481), ('cx', 374), ('sx', 241), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 210
# Operations full_circuit OrderedDict([('rz', 122), ('cx', 109), ('sx', 53), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 795
# Operations full_circuit OrderedDict([('rz', 435), ('cx', 411), ('sx', 196), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 209
# Operations full_circuit OrderedDict([('rz', 125), ('cx', 109), ('sx', 55), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 782
# Operations full_circuit OrderedDict([('rz', 466), ('cx', 379), ('sx', 227), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 190
# Operations full_circuit OrderedDict([('rz', 119), ('cx', 109), ('sx', 48), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 786
# Operations full_circuit OrderedDict([('rz', 479), ('cx', 371), ('sx', 239), ('x', 55), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 196
# Operations full_circuit OrderedDict([('rz', 129), ('cx', 109), ('sx', 60), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 755
# Operations full_circuit OrderedDict([('rz', 426), ('cx', 396), ('sx', 195), ('x', 51), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 193
# Operations full_circuit OrderedDict([('rz', 127), ('cx', 111), ('sx', 56), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 795
# Operations full_circuit OrderedDict([('cx', 446), ('rz', 426), ('sx', 191), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 206
# Operations full_circuit OrderedDict([('rz', 130), ('cx', 109), ('sx', 61), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 787
# Operations full_circuit OrderedDict([('rz', 423), ('cx', 390), ('sx', 183), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 196
# Operations full_circuit OrderedDict([('rz', 129), ('cx', 109), ('sx', 60), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 798
# Operations full_circuit OrderedDict([('cx', 452), ('rz', 431), ('sx', 191), ('x', 53), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 206
# Operations full_circuit OrderedDict([('rz', 132), ('cx', 109), ('sx', 63), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 800
# Operations full_circuit OrderedDict([('rz', 422), ('cx', 404), ('sx', 181), ('x', 57), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 183
# Operations full_circuit OrderedDict([('rz', 107), ('cx', 105), ('sx', 38), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 762
# Operations full_circuit OrderedDict([('rz', 436), ('cx', 394), ('sx', 197), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 175
# Operations full_circuit OrderedDict([('rz', 111), ('cx', 100), ('sx', 40), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 770
# Operations full_circuit OrderedDict([('rz', 430), ('cx', 397), ('sx', 183), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 184
# Operations full_circuit OrderedDict([('rz', 108), ('cx', 103), ('sx', 40), ('barrier', 9), ('x', 7), ('reset', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 775
# Operations full_circuit OrderedDict([('rz', 464), ('cx', 382), ('sx', 221), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 181
# Operations full_circuit OrderedDict([('rz', 111), ('cx', 101), ('sx', 44), ('barrier', 9), ('x', 8), ('reset', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 787
# Operations full_circuit OrderedDict([('rz', 423), ('cx', 390), ('sx', 181), ('x', 62), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 179
# Operations full_circuit OrderedDict([('rz', 119), ('cx', 95), ('sx', 47), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 770
# Operations full_circuit OrderedDict([('rz', 428), ('cx', 396), ('sx', 181), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 217
# Operations full_circuit OrderedDict([('rz', 126), ('cx', 108), ('sx', 57), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 763
# Operations full_circuit OrderedDict([('rz', 441), ('cx', 389), ('sx', 203), ('x', 53), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 198
# Operations full_circuit OrderedDict([('rz', 123), ('cx', 113), ('sx', 52), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 795
# Operations full_circuit OrderedDict([('cx', 446), ('rz', 426), ('sx', 191), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 224
# Operations full_circuit OrderedDict([('rz', 130), ('cx', 112), ('sx', 63), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 787
# Operations full_circuit OrderedDict([('rz', 423), ('cx', 390), ('sx', 183), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 196
# Operations full_circuit OrderedDict([('rz', 129), ('cx', 109), ('sx', 60), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 795
# Operations full_circuit OrderedDict([('cx', 446), ('rz', 426), ('sx', 191), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 205
# Operations full_circuit OrderedDict([('rz', 127), ('cx', 111), ('sx', 57), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 770
# Operations full_circuit OrderedDict([('rz', 454), ('cx', 384), ('sx', 219), ('x', 53), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 195
# Operations full_circuit OrderedDict([('rz', 128), ('cx', 111), ('sx', 58), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 793
# Operations full_circuit OrderedDict([('rz', 419), ('cx', 401), ('sx', 181), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 184
# Operations full_circuit OrderedDict([('rz', 110), ('cx', 103), ('sx', 42), ('barrier', 9), ('x', 7), ('reset', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 787
# Operations full_circuit OrderedDict([('rz', 423), ('cx', 390), ('sx', 181), ('x', 62), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 181
# Operations full_circuit OrderedDict([('rz', 119), ('cx', 99), ('sx', 49), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 793
# Operations full_circuit OrderedDict([('rz', 433), ('cx', 411), ('sx', 192), ('x', 56), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 179
# Operations full_circuit OrderedDict([('cx', 107), ('rz', 104), ('sx', 32), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 770
# Operations full_circuit OrderedDict([('rz', 430), ('cx', 397), ('sx', 183), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 186
# Operations full_circuit OrderedDict([('rz', 111), ('cx', 100), ('sx', 41), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 785
# Operations full_circuit OrderedDict([('rz', 412), ('cx', 397), ('sx', 173), ('x', 61), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 174
# Operations full_circuit OrderedDict([('rz', 112), ('cx', 97), ('sx', 42), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 787
# Operations full_circuit OrderedDict([('rz', 421), ('cx', 389), ('sx', 179), ('x', 62), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 201
# Operations full_circuit OrderedDict([('rz', 129), ('cx', 105), ('sx', 57), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 2)])
# debug 3
# transpiled depth qc full_circuit 768
# Operations full_circuit OrderedDict([('rz', 451), ('cx', 383), ('sx', 215), ('x', 55), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 206
# Operations full_circuit OrderedDict([('rz', 130), ('cx', 109), ('sx', 61), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 787
# Operations full_circuit OrderedDict([('rz', 423), ('cx', 390), ('sx', 183), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 217
# Operations full_circuit OrderedDict([('rz', 131), ('cx', 112), ('sx', 61), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 792
# Operations full_circuit OrderedDict([('rz', 491), ('cx', 368), ('sx', 251), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 208
# Operations full_circuit OrderedDict([('rz', 126), ('cx', 114), ('sx', 56), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 784
# Operations full_circuit OrderedDict([('rz', 416), ('cx', 392), ('sx', 179), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 218
# Operations full_circuit OrderedDict([('rz', 127), ('cx', 114), ('sx', 57), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 784
# Operations full_circuit OrderedDict([('rz', 416), ('cx', 392), ('sx', 179), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 206
# Operations full_circuit OrderedDict([('rz', 132), ('cx', 109), ('sx', 63), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 768
# Operations full_circuit OrderedDict([('rz', 429), ('cx', 403), ('sx', 188), ('x', 55), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 176
# Operations full_circuit OrderedDict([('rz', 109), ('cx', 105), ('sx', 38), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 791
# Operations full_circuit OrderedDict([('rz', 429), ('cx', 413), ('sx', 188), ('x', 56), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 181
# Operations full_circuit OrderedDict([('rz', 117), ('cx', 101), ('sx', 45), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 2)])
# debug 3
# transpiled depth qc full_circuit 775
# Operations full_circuit OrderedDict([('rz', 459), ('cx', 384), ('sx', 217), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 183
# Operations full_circuit OrderedDict([('rz', 105), ('cx', 105), ('sx', 36), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 770
# Operations full_circuit OrderedDict([('rz', 448), ('cx', 388), ('sx', 209), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 183
# Operations full_circuit OrderedDict([('rz', 105), ('cx', 105), ('sx', 36), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 784
# Operations full_circuit OrderedDict([('rz', 416), ('cx', 392), ('sx', 177), ('x', 62), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 172
# Operations full_circuit OrderedDict([('rz', 110), ('cx', 99), ('sx', 38), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 787
# Operations full_circuit OrderedDict([('rz', 421), ('cx', 389), ('sx', 179), ('x', 62), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 200
# Operations full_circuit OrderedDict([('rz', 125), ('cx', 107), ('sx', 55), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 789
# Operations full_circuit OrderedDict([('rz', 417), ('cx', 394), ('sx', 177), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 205
# Operations full_circuit OrderedDict([('rz', 129), ('cx', 111), ('sx', 59), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 795
# Operations full_circuit OrderedDict([('rz', 419), ('cx', 401), ('sx', 181), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 200
# Operations full_circuit OrderedDict([('rz', 131), ('cx', 111), ('sx', 55), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 2)])
# debug 3
# transpiled depth qc full_circuit 771
# Operations full_circuit OrderedDict([('rz', 431), ('cx', 397), ('sx', 187), ('x', 56), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 183
# Operations full_circuit OrderedDict([('rz', 123), ('cx', 115), ('sx', 50), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 772
# Operations full_circuit OrderedDict([('rz', 451), ('cx', 388), ('sx', 213), ('x', 50), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 199
# Operations full_circuit OrderedDict([('rz', 135), ('cx', 109), ('sx', 59), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 2)])
# debug 3
# transpiled depth qc full_circuit 801
# Operations full_circuit OrderedDict([('rz', 420), ('cx', 398), ('sx', 182), ('x', 59), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 183
# Operations full_circuit OrderedDict([('rz', 125), ('cx', 115), ('sx', 52), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 1)])
# debug 3
# transpiled depth qc full_circuit 770
# Operations full_circuit OrderedDict([('rz', 430), ('cx', 399), ('sx', 185), ('x', 56), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 192
# Operations full_circuit OrderedDict([('rz', 111), ('cx', 108), ('sx', 40), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 797
# Operations full_circuit OrderedDict([('rz', 425), ('cx', 399), ('sx', 183), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 176
# Operations full_circuit OrderedDict([('rz', 109), ('cx', 102), ('sx', 38), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 771
# Operations full_circuit OrderedDict([('rz', 431), ('cx', 397), ('sx', 185), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 187
# Operations full_circuit OrderedDict([('rz', 116), ('cx', 98), ('sx', 47), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 794
# Operations full_circuit OrderedDict([('rz', 434), ('cx', 411), ('sx', 194), ('x', 56), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 183
# Operations full_circuit OrderedDict([('rz', 107), ('cx', 105), ('sx', 38), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 786
# Operations full_circuit OrderedDict([('rz', 418), ('cx', 392), ('sx', 179), ('x', 62), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 192
# Operations full_circuit OrderedDict([('rz', 116), ('cx', 97), ('sx', 45), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 773
# Operations full_circuit OrderedDict([('rz', 455), ('cx', 383), ('sx', 217), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 202
# Operations full_circuit OrderedDict([('rz', 134), ('cx', 103), ('sx', 63), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 785
# Operations full_circuit OrderedDict([('rz', 415), ('cx', 391), ('sx', 176), ('x', 61), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 195
# Operations full_circuit OrderedDict([('rz', 125), ('cx', 113), ('sx', 53), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 776
# Operations full_circuit OrderedDict([('rz', 468), ('cx', 380), ('sx', 228), ('x', 53), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 206
# Operations full_circuit OrderedDict([('rz', 132), ('cx', 109), ('sx', 62), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 779
# Operations full_circuit OrderedDict([('rz', 471), ('cx', 378), ('sx', 232), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 205
# Operations full_circuit OrderedDict([('rz', 129), ('cx', 111), ('sx', 58), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 782
# Operations full_circuit OrderedDict([('rz', 473), ('cx', 378), ('sx', 232), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 196
# Operations full_circuit OrderedDict([('rz', 131), ('cx', 109), ('sx', 61), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 787
# Operations full_circuit OrderedDict([('rz', 481), ('cx', 372), ('sx', 244), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 195
# Operations full_circuit OrderedDict([('rz', 127), ('cx', 113), ('sx', 55), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 781
# Operations full_circuit OrderedDict([('rz', 471), ('cx', 378), ('sx', 234), ('x', 53), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 186
# Operations full_circuit OrderedDict([('rz', 115), ('cx', 100), ('sx', 44), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 802
# Operations full_circuit OrderedDict([('rz', 426), ('cx', 396), ('sx', 183), ('x', 61), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 190
# Operations full_circuit OrderedDict([('rz', 115), ('cx', 101), ('sx', 45), ('barrier', 9), ('x', 7), ('reset', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 787
# Operations full_circuit OrderedDict([('rz', 424), ('cx', 390), ('sx', 182), ('x', 62), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 194
# Operations full_circuit OrderedDict([('rz', 111), ('cx', 103), ('sx', 42), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 801
# Operations full_circuit OrderedDict([('rz', 436), ('cx', 395), ('sx', 190), ('x', 62), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 184
# Operations full_circuit OrderedDict([('rz', 110), ('cx', 103), ('sx', 41), ('barrier', 9), ('x', 7), ('reset', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 765
# Operations full_circuit OrderedDict([('rz', 451), ('cx', 388), ('sx', 210), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 179
# Operations full_circuit OrderedDict([('rz', 121), ('cx', 95), ('sx', 48), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 784
# Operations full_circuit OrderedDict([('rz', 478), ('cx', 373), ('sx', 236), ('x', 57), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 182
# Operations full_circuit OrderedDict([('rz', 119), ('cx', 109), ('sx', 50), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 769
# Operations full_circuit OrderedDict([('rz', 444), ('cx', 389), ('sx', 205), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 206
# Operations full_circuit OrderedDict([('rz', 132), ('cx', 109), ('sx', 63), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 786
# Operations full_circuit OrderedDict([('rz', 418), ('cx', 392), ('sx', 181), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 195
# Operations full_circuit OrderedDict([('rz', 128), ('cx', 111), ('sx', 58), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 773
# Operations full_circuit OrderedDict([('rz', 453), ('cx', 386), ('sx', 217), ('x', 51), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 205
# Operations full_circuit OrderedDict([('rz', 129), ('cx', 111), ('sx', 59), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 790
# Operations full_circuit OrderedDict([('rz', 414), ('cx', 397), ('sx', 177), ('x', 59), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 205
# Operations full_circuit OrderedDict([('rz', 129), ('cx', 111), ('sx', 59), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 780
# Operations full_circuit OrderedDict([('rz', 466), ('cx', 380), ('sx', 229), ('x', 54), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 211
# Operations full_circuit OrderedDict([('rz', 130), ('cx', 114), ('sx', 60), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 768
# Operations full_circuit OrderedDict([('rz', 447), ('cx', 388), ('sx', 215), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 190
# Operations full_circuit OrderedDict([('rz', 113), ('cx', 103), ('sx', 45), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 794
# Operations full_circuit OrderedDict([('rz', 435), ('cx', 411), ('sx', 194), ('x', 56), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 189
# Operations full_circuit OrderedDict([('rz', 112), ('cx', 103), ('sx', 42), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 797
# Operations full_circuit OrderedDict([('rz', 419), ('cx', 401), ('sx', 179), ('x', 61), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 191
# Operations full_circuit OrderedDict([('rz', 109), ('cx', 105), ('sx', 39), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 770
# Operations full_circuit OrderedDict([('rz', 428), ('cx', 399), ('sx', 181), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 177
# Operations full_circuit OrderedDict([('rz', 115), ('cx', 98), ('sx', 46), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 788
# Operations full_circuit OrderedDict([('rz', 424), ('cx', 390), ('sx', 183), ('x', 62), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 179
# Operations full_circuit OrderedDict([('rz', 121), ('cx', 95), ('sx', 49), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 792
# Operations full_circuit OrderedDict([('rz', 489), ('cx', 367), ('sx', 249), ('x', 57), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 192
# Operations full_circuit OrderedDict([('rz', 124), ('cx', 106), ('sx', 52), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 785
# Operations full_circuit OrderedDict([('rz', 418), ('cx', 388), ('sx', 179), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 201
# Operations full_circuit OrderedDict([('rz', 131), ('cx', 105), ('sx', 61), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 800
# Operations full_circuit OrderedDict([('rz', 423), ('cx', 395), ('sx', 184), ('x', 58), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 196
# Operations full_circuit OrderedDict([('rz', 127), ('cx', 107), ('sx', 56), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 785
# Operations full_circuit OrderedDict([('rz', 421), ('cx', 389), ('sx', 183), ('x', 59), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 191
# Operations full_circuit OrderedDict([('rz', 128), ('cx', 104), ('sx', 56), ('barrier', 9), ('reset', 6), ('measure', 4), ('x', 3)])
# debug 3
# transpiled depth qc full_circuit 775
# Operations full_circuit OrderedDict([('rz', 464), ('cx', 379), ('sx', 227), ('x', 52), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 192
# Operations full_circuit OrderedDict([('rz', 131), ('cx', 102), ('sx', 60), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 785
# Operations full_circuit OrderedDict([('rz', 421), ('cx', 389), ('sx', 183), ('x', 59), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 203
# Operations full_circuit OrderedDict([('rz', 127), ('cx', 104), ('sx', 58), ('barrier', 9), ('reset', 6), ('x', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 786
# Operations full_circuit OrderedDict([('rz', 414), ('cx', 396), ('sx', 177), ('x', 57), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 176
# Operations full_circuit OrderedDict([('rz', 112), ('cx', 96), ('sx', 42), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 800
# Operations full_circuit OrderedDict([('rz', 423), ('cx', 395), ('sx', 182), ('x', 60), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 184
# Operations full_circuit OrderedDict([('rz', 106), ('cx', 98), ('sx', 36), ('barrier', 9), ('reset', 6), ('x', 5), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 785
# Operations full_circuit OrderedDict([('rz', 421), ('cx', 389), ('sx', 181), ('x', 61), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 179
# Operations full_circuit OrderedDict([('rz', 115), ('cx', 94), ('sx', 45), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 782
# Operations full_circuit OrderedDict([('rz', 477), ('cx', 375), ('sx', 233), ('x', 51), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 184
# Operations full_circuit OrderedDict([('rz', 108), ('cx', 99), ('sx', 40), ('barrier', 9), ('x', 7), ('reset', 6), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 774
# Operations full_circuit OrderedDict([('rz', 463), ('cx', 379), ('sx', 225), ('x', 53), ('barrier', 9), ('reset', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 172
# Operations full_circuit OrderedDict([('rz', 110), ('cx', 98), ('sx', 38), ('barrier', 9), ('reset', 6), ('x', 4), ('measure', 4)])
# debug 3
# transpiled depth qc full_circuit 768
# Operations full_circuit OrderedDict([('rz', 428), ('cx', 395), ('sx', 181), ('x', 56), ('barrier', 9), ('reset', 4), ('measure', 4)])

# %% [markdown]
# ___
#
# Then, the classical Mamdani system is implemented by using the python library Sci-kit Fuzzy. The following cells initializes the system as required from the library

# %%
from skfuzzy import control as ctrl

# %%
env_l = ctrl.Antecedent(env_light, 'env_light')
cng_r = ctrl.Antecedent(changing_rate , 'change_rate')
dim = ctrl.Consequent(dimmer_control, 'dimmer_ctrl')

env_l['dark'] = l_dark
env_l['medium'] = l_medium
env_l['light'] = l_light 

cng_r['neg_small'] = r_ns
cng_r['zero'] = r_zero
cng_r['pos_small'] = r_ps 

dim['very_small'] = dm_vs
dim['small'] = dm_s
dim['big'] = dm_b
dim['very_big'] = dm_vb


rule1 = ctrl.Rule(env_l['dark'] & cng_r['pos_small'], dim['big'])
rule2 = ctrl.Rule(env_l['dark'] & cng_r['zero'], dim['big'])
rule3 = ctrl.Rule(env_l['dark'] & cng_r['neg_small'], dim['very_big'])
rule4 = ctrl.Rule(env_l['medium'] & cng_r['pos_small'], dim['small'])
rule5 = ctrl.Rule(env_l['medium'] & cng_r['zero'], dim['big'])
rule6 = ctrl.Rule(env_l['medium'] & cng_r['neg_small'], dim['big'])
rule7 = ctrl.Rule(env_l['light'] & cng_r['pos_small'], dim['very_small'])
rule8 = ctrl.Rule(env_l['light'] & cng_r['zero'], dim['small'])
rule9 = ctrl.Rule(env_l['light'] & cng_r['neg_small'], dim['big'])

dim_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9])
dim_sys = ctrl.ControlSystemSimulation(dim_ctrl)

# %% [markdown]
# By running the following cell, the same combinations of inputs are passed to the classical control which computes the 121 output. All the output values are stored in a list.

# %%
f_classical = []
for el in el_list:
    for cr in cr_list:
        dim_sys.input['env_light']=el    
        dim_sys.input['change_rate']=cr

        dim_sys.compute()
        f_classical.append(dim_sys.output['dimmer_ctrl'])

# %% [markdown]
# At this point, both the QFIE and Classical system' control surfaces can be plotted. Firstly, the following cell shows the former surface.

# %%
from mpl_toolkits.mplot3d import Axes3D

X, Y, = el_list, cr_list
plotx,ploty, = np.meshgrid(np.linspace(np.min(X),np.max(X),11), np.linspace(np.min(Y),np.max(Y),11))
Z = np.zeros_like(plotx)
counter = 0 
for i in range(len(el_list)):
    for j in range(len(cr_list)):
        Z[i,j]=f_quantum_linear[counter]
        counter+=1
        
zfig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(plotx, ploty, Z, rstride=1, cstride=1, cmap='viridis',
                       linewidth=0.4, antialiased=True)
ax.set_xlabel('Environment Light')
ax.set_ylabel('Changing Rate')
ax.set_zlabel('Dimmer Control')
# Out:
# Text(0.5, 0, 'Dimmer Control')

# %% [markdown]
# Then, the classical surface is displayed by running the following cell.

# %%
X, Y, = el_list, cr_list
plotx,ploty, = np.meshgrid(np.linspace(np.min(X),np.max(X),11), np.linspace(np.min(Y),np.max(Y),11))
Z = np.zeros_like(plotx)
counter = 0 
for i in range(len(el_list)):
    for j in range(len(cr_list)):
        Z[i,j]=f_quantum_log[counter]
        counter+=1
        
zfig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(plotx, ploty, Z, rstride=1, cstride=1, cmap='viridis',
                       linewidth=0.4, antialiased=True)
ax.set_xlabel('Environment Light')
ax.set_ylabel('Changing Rate')
ax.set_zlabel('Dimmer Control')
# Out:
# Text(0.5, 0, 'Dimmer Control')

# %%
X, Y, = el_list, cr_list
plotx,ploty, = np.meshgrid(np.linspace(np.min(X),np.max(X),11), np.linspace(np.min(Y),np.max(Y),11))
Z = np.zeros_like(plotx)
counter = 0 
for i in range(len(el_list)):
    for j in range(len(cr_list)):
        Z[i,j]=f_classical[counter]
        counter+=1
        
zfig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(plotx, ploty, Z, rstride=1, cstride=1, cmap='viridis',
                       linewidth=0.4, antialiased=True)
ax.set_xlabel('Environment Light')
ax.set_ylabel('Changing Rate')
ax.set_zlabel('Dimmer Control')
# Out:
# Text(0.5, 0, 'Dimmer Control')

# %% [markdown]
# The two surfaces show how QFIE is able to control in a very similar way to a classical Mamdani fuzzy control the lighting control system, despite the computational advantage in firing the fuzzy rules in a parallel way.
