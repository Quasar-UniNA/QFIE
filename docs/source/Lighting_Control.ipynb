# %% [markdown]
# # QFIE For Lighting Controller System
# This notebook aims to illustrate how QFIE can control efficiently a lighting system, in  which  the  control system dim the bulb light automatically according to the environmental Light. Two input variables are considered, namely the environment light and the  changing  rate of the environmental light. Finally, the control surface of the system will be obtained both using QFIE and the canonical Mamdani fuzzy system, which configuration is reported in the paper.
#
# Firstly, let us import the required libraries.

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
import QFIE.FuzzyEngines as FE

# %% [markdown]
# The system is a MISO composed of two input variables and one output variable. In detail:
#
# Inputs:
#
# - Environment Light (env_light): three linguistic terms are considered: 'Dark', 'Medium', 'Light'
#
# - Changing Rate (change_rate): three lingiuistic terms are considered: 'Negative Small', 'Zero', 'Positive Small'
#
# Output:
#
# - Dimmer Control (dimmer_ctrl): four linguistic terms are considered: 'Very Small', 'Small', 'Big', 'Very Big'
#
#
# By running the following cell, the fuzzy sets used are graphically shown.

# %%
env_light = np.linspace(120, 220, 200)
changing_rate = np.linspace(-10, 10, 200)
dimmer_control = np.linspace(0, 10, 200)



l_dark = fuzz.trapmf(env_light, [120,120,130,150])
l_medium = fuzz.trapmf(env_light, [130,  150, 190,210])
l_light = fuzz.trapmf(env_light, [190,  210, 220, 220])

r_ns = fuzz.trimf(changing_rate, [-10,-10,0])
r_zero = fuzz.trimf(changing_rate, [-10,0,10])
r_ps = fuzz.trimf(changing_rate, [0,10,10])

dm_vs = fuzz.trapmf(dimmer_control, [0,0,2,4])
dm_s = fuzz.trimf(dimmer_control, [2,4,6])
dm_b = fuzz.trimf(dimmer_control, [4,6,8])
dm_vb = fuzz.trapmf(dimmer_control, [6,8,10,10])




# Visualize these universes and membership functions
fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(10, 12))


ax0.plot(env_light, l_dark, 'b', linewidth=1.5, label='dark')
ax0.plot(env_light, l_medium, 'g', linewidth=1.5, label='medium')
ax0.plot(env_light, l_light, 'r', linewidth=1.5, label='light')
ax0.set_title('Environment Light')
ax0.legend()

ax1.plot(changing_rate, r_ns, 'b', linewidth=1.5, label='negative small')
ax1.plot(changing_rate, r_zero, 'g', linewidth=1.5, label='zero')
ax1.plot(changing_rate, r_ps, 'r', linewidth=1.5, label='positive small')
ax1.set_title('Changing Rate')
ax1.legend()


ax2.plot(dimmer_control, dm_vs, 'b', linewidth=1.5, label='very small')
ax2.plot(dimmer_control, dm_s, 'g', linewidth=1.5, label='small')
ax2.plot(dimmer_control, dm_b, 'r', linewidth=1.5, label='big')
ax2.plot(dimmer_control, dm_vb, 'y', linewidth=1.5, label='very big')
ax2.set_title('Dimmer control')
ax2.legend()

# Turn off top/right axes
for ax in (ax0, ax1, ax2):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()


plt.show()

# %% [markdown]
# The rules base of the system is composed of the following rules:
#
# - if env_light is dark and change_rate is pos_small then dimmer_ctrl is big
# - if env_light is dark and change_rate is zero then dimmer_ctrl is big
# - if env_light is dark and change_rate is neg_small then dimmer_ctrl is very_big
# - if env_light is medium and change_rate is pos_small then dimmer_ctrl is small
# - if env_light is medium and change_rate is zero then dimmer_ctrl is big
# - if env_light is medium and change_rate is neg_small then dimmer_ctrl is big
# - if env_light is light and change_rate is pos_small then dimmer_ctrl is very_small
# - if env_light is light and change_rate is zero then dimmer_ctrl is small
# - if env_light is light and change_rate is neg_small then dimmer_ctrl is big
#
# By running the following two cells QFIE is properly initialized

# %%
rules = ['if env_light is dark and change_rate is pos_small then dimmer_ctrl is big',
         'if env_light is dark and change_rate is zero then dimmer_ctrl is big',
         'if env_light is dark and change_rate is neg_small then dimmer_ctrl is very_big',
         'if env_light is medium and change_rate is pos_small then dimmer_ctrl is small',
         'if env_light is medium and change_rate is zero then dimmer_ctrl is big',
         'if env_light is medium and change_rate is neg_small then dimmer_ctrl is big',
         'if env_light is light and change_rate is pos_small then dimmer_ctrl is very_small',
         'if env_light is light and change_rate is zero then dimmer_ctrl is small',
         'if env_light is light and change_rate is neg_small then dimmer_ctrl is big']

# %%
qfie = FE.QuantumFuzzyEngine()
qfie.input_variable(name='env_light', range=env_light)
qfie.input_variable(name='change_rate', range=changing_rate)
qfie.output_variable(name='dimmer_ctrl', range=dimmer_control)

qfie.add_input_fuzzysets(var_name='env_light', set_names=['dark', 'medium', 'light'], sets=[l_dark, l_medium, l_light])
qfie.add_input_fuzzysets(var_name='change_rate', set_names=['neg_small', 'zero', 'pos_small'], sets=[r_ns, r_zero, r_ps])
qfie.add_output_fuzzysets(var_name='dimmer_ctrl', set_names=['very_small', 'small', 'big', 'very_big'],sets=[dm_vs, dm_s, dm_b, dm_vb])
qfie.set_rules(rules)

# %% [markdown]
# To obtain the control surface of QFIE, it is used to fire the rules in 121 different input combinations. In detail, for 11 values of env_light 11 different values of change_rate are considered. The 121 outputs obtained are collected in a list which will be used at the end of the notebook to plot the control surface.

# %%
el_list, cr_list = [t for t in range(120, 230, 10)], [s for s in range(-10, 12, 2)]
f_quantum = []
for el in el_list:
    for cr in cr_list:
        qfie.build_inference_qc({'env_light':el, 'change_rate':cr}, draw_qc=False)
        f_quantum.append(qfie.execute('qasm_simulator', 6400, plot_histo=False)[0])
# Out:
# {'env_light': 120, 'change_rate': -10}
# Input values  {'env_light': [1.0, 0.0, 0.0], 'change_rate': [1.0, 0.0, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0, '1000': 1.0}
# {'env_light': 120, 'change_rate': -8}
# Input values  {'env_light': [1.0, 0.0, 0.0], 'change_rate': [0.8, 0.2, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.2046875, '1000': 0.7953125}
# {'env_light': 120, 'change_rate': -6}
# Input values  {'env_light': [1.0, 0.0, 0.0], 'change_rate': [0.6, 0.4, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.40796875, '1000': 0.59203125}
# {'env_light': 120, 'change_rate': -4}
# Input values  {'env_light': [1.0, 0.0, 0.0], 'change_rate': [0.39999999999999997, 0.6, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.601875, '1000': 0.398125}
# {'env_light': 120, 'change_rate': -2}
# Input values  {'env_light': [1.0, 0.0, 0.0], 'change_rate': [0.2, 0.8, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.79875, '1000': 0.20125}
# {'env_light': 120, 'change_rate': 0}
# Input values  {'env_light': [1.0, 0.0, 0.0], 'change_rate': [0.002512562814070352, 0.9949748743718593, 0.0025125628140703514]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.99671875, '1000': 0.00328125}
# {'env_light': 120, 'change_rate': 2}
# Input values  {'env_light': [1.0, 0.0, 0.0], 'change_rate': [0.0, 0.7999999999999999, 0.19999999999999998]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 120, 'change_rate': 4}
# Input values  {'env_light': [1.0, 0.0, 0.0], 'change_rate': [0.0, 0.6, 0.4]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 120, 'change_rate': 6}
# Input values  {'env_light': [1.0, 0.0, 0.0], 'change_rate': [0.0, 0.4, 0.6]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 120, 'change_rate': 8}
# Input values  {'env_light': [1.0, 0.0, 0.0], 'change_rate': [0.0, 0.2, 0.8]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 120, 'change_rate': 10}
# Input values  {'env_light': [1.0, 0.0, 0.0], 'change_rate': [0.0, 0.0, 1.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 130, 'change_rate': -10}
# Input values  {'env_light': [0.997738693467337, 0.0022613065326629995, 0.0], 'change_rate': [1.0, 0.0, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.00140625, '1000': 0.99859375}
# {'env_light': 130, 'change_rate': -8}
# Input values  {'env_light': [0.997738693467337, 0.0022613065326629995, 0.0], 'change_rate': [0.8, 0.2, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.20203125, '1000': 0.79796875}
# {'env_light': 130, 'change_rate': -6}
# Input values  {'env_light': [0.997738693467337, 0.0022613065326629995, 0.0], 'change_rate': [0.6, 0.4, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.40140625, '1000': 0.59859375}
# {'env_light': 130, 'change_rate': -4}
# Input values  {'env_light': [0.997738693467337, 0.0022613065326629995, 0.0], 'change_rate': [0.39999999999999997, 0.6, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.5978125, '1000': 0.4021875}
# {'env_light': 130, 'change_rate': -2}
# Input values  {'env_light': [0.997738693467337, 0.0022613065326629995, 0.0], 'change_rate': [0.2, 0.8, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.804375, '1000': 0.195625}
# {'env_light': 130, 'change_rate': 0}
# Input values  {'env_light': [0.997738693467337, 0.0022613065326629995, 0.0], 'change_rate': [0.002512562814070352, 0.9949748743718593, 0.0025125628140703514]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.9953125, '1000': 0.0046875}
# {'env_light': 130, 'change_rate': 2}
# Input values  {'env_light': [0.997738693467337, 0.0022613065326629995, 0.0], 'change_rate': [0.0, 0.7999999999999999, 0.19999999999999998]}
# Output Counts {'0001': 0, '0010': 0.00078125, '0100': 0.99921875, '1000': 0}
# {'env_light': 130, 'change_rate': 4}
# Input values  {'env_light': [0.997738693467337, 0.0022613065326629995, 0.0], 'change_rate': [0.0, 0.6, 0.4]}
# Output Counts {'0001': 0, '0010': 0.00109375, '0100': 0.99890625, '1000': 0}
# {'env_light': 130, 'change_rate': 6}
# Input values  {'env_light': [0.997738693467337, 0.0022613065326629995, 0.0], 'change_rate': [0.0, 0.4, 0.6]}
# Output Counts {'0001': 0, '0010': 0.00140625, '0100': 0.99859375, '1000': 0}
# {'env_light': 130, 'change_rate': 8}
# Input values  {'env_light': [0.997738693467337, 0.0022613065326629995, 0.0], 'change_rate': [0.0, 0.2, 0.8]}
# Output Counts {'0001': 0, '0010': 0.00234375, '0100': 0.99765625, '1000': 0}
# {'env_light': 130, 'change_rate': 10}
# Input values  {'env_light': [0.997738693467337, 0.0022613065326629995, 0.0], 'change_rate': [0.0, 0.0, 1.0]}
# Output Counts {'0001': 0, '0010': 0.0015625, '0100': 0.9984375, '1000': 0}
# {'env_light': 140, 'change_rate': -10}
# Input values  {'env_light': [0.5, 0.5, 0.0], 'change_rate': [1.0, 0.0, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.49234375, '1000': 0.50765625}
# {'env_light': 140, 'change_rate': -8}
# Input values  {'env_light': [0.5, 0.5, 0.0], 'change_rate': [0.8, 0.2, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.60265625, '1000': 0.39734375}
# {'env_light': 140, 'change_rate': -6}
# Input values  {'env_light': [0.5, 0.5, 0.0], 'change_rate': [0.6, 0.4, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.70171875, '1000': 0.29828125}
# {'env_light': 140, 'change_rate': -4}
# Input values  {'env_light': [0.5, 0.5, 0.0], 'change_rate': [0.39999999999999997, 0.6, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.80453125, '1000': 0.19546875}
# {'env_light': 140, 'change_rate': -2}
# Input values  {'env_light': [0.5, 0.5, 0.0], 'change_rate': [0.2, 0.8, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.8946875, '1000': 0.1053125}
# {'env_light': 140, 'change_rate': 0}
# Input values  {'env_light': [0.5, 0.5, 0.0], 'change_rate': [0.002512562814070352, 0.9949748743718593, 0.0025125628140703514]}
# Output Counts {'0001': 0, '0010': 0.000625, '0100': 0.9978125, '1000': 0.0015625}
# {'env_light': 140, 'change_rate': 2}
# Input values  {'env_light': [0.5, 0.5, 0.0], 'change_rate': [0.0, 0.7999999999999999, 0.19999999999999998]}
# Output Counts {'0001': 0, '0010': 0.099375, '0100': 0.900625, '1000': 0}
# {'env_light': 140, 'change_rate': 4}
# Input values  {'env_light': [0.5, 0.5, 0.0], 'change_rate': [0.0, 0.6, 0.4]}
# Output Counts {'0001': 0, '0010': 0.20375, '0100': 0.79625, '1000': 0}
# {'env_light': 140, 'change_rate': 6}
# Input values  {'env_light': [0.5, 0.5, 0.0], 'change_rate': [0.0, 0.4, 0.6]}
# Output Counts {'0001': 0, '0010': 0.29734375, '0100': 0.70265625, '1000': 0}
# {'env_light': 140, 'change_rate': 8}
# Input values  {'env_light': [0.5, 0.5, 0.0], 'change_rate': [0.0, 0.2, 0.8]}
# Output Counts {'0001': 0, '0010': 0.399375, '0100': 0.600625, '1000': 0}
# {'env_light': 140, 'change_rate': 10}
# Input values  {'env_light': [0.5, 0.5, 0.0], 'change_rate': [0.0, 0.0, 1.0]}
# Output Counts {'0001': 0, '0010': 0.50859375, '0100': 0.49140625, '1000': 0}
# {'env_light': 150, 'change_rate': -10}
# Input values  {'env_light': [0.005276381909547852, 0.9947236180904522, 0.0], 'change_rate': [1.0, 0.0, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.994375, '1000': 0.005625}
# {'env_light': 150, 'change_rate': -8}
# Input values  {'env_light': [0.005276381909547852, 0.9947236180904522, 0.0], 'change_rate': [0.8, 0.2, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.99578125, '1000': 0.00421875}
# {'env_light': 150, 'change_rate': -6}
# Input values  {'env_light': [0.005276381909547852, 0.9947236180904522, 0.0], 'change_rate': [0.6, 0.4, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.9965625, '1000': 0.0034375}
# {'env_light': 150, 'change_rate': -4}
# Input values  {'env_light': [0.005276381909547852, 0.9947236180904522, 0.0], 'change_rate': [0.39999999999999997, 0.6, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.99796875, '1000': 0.00203125}
# {'env_light': 150, 'change_rate': -2}
# Input values  {'env_light': [0.005276381909547852, 0.9947236180904522, 0.0], 'change_rate': [0.2, 0.8, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 0.99875, '1000': 0.00125}
# {'env_light': 150, 'change_rate': 0}
# Input values  {'env_light': [0.005276381909547852, 0.9947236180904522, 0.0], 'change_rate': [0.002512562814070352, 0.9949748743718593, 0.0025125628140703514]}
# Output Counts {'0001': 0, '0010': 0.00359375, '0100': 0.99640625, '1000': 0}
# {'env_light': 150, 'change_rate': 2}
# Input values  {'env_light': [0.005276381909547852, 0.9947236180904522, 0.0], 'change_rate': [0.0, 0.7999999999999999, 0.19999999999999998]}
# Output Counts {'0001': 0, '0010': 0.201875, '0100': 0.798125, '1000': 0}
# {'env_light': 150, 'change_rate': 4}
# Input values  {'env_light': [0.005276381909547852, 0.9947236180904522, 0.0], 'change_rate': [0.0, 0.6, 0.4]}
# Output Counts {'0001': 0, '0010': 0.3978125, '0100': 0.6021875, '1000': 0}
# {'env_light': 150, 'change_rate': 6}
# Input values  {'env_light': [0.005276381909547852, 0.9947236180904522, 0.0], 'change_rate': [0.0, 0.4, 0.6]}
# Output Counts {'0001': 0, '0010': 0.58625, '0100': 0.41375, '1000': 0}
# {'env_light': 150, 'change_rate': 8}
# Input values  {'env_light': [0.005276381909547852, 0.9947236180904522, 0.0], 'change_rate': [0.0, 0.2, 0.8]}
# Output Counts {'0001': 0, '0010': 0.79953125, '0100': 0.20046875, '1000': 0}
# {'env_light': 150, 'change_rate': 10}
# Input values  {'env_light': [0.005276381909547852, 0.9947236180904522, 0.0], 'change_rate': [0.0, 0.0, 1.0]}
# Output Counts {'0001': 0, '0010': 0.99515625, '0100': 0.00484375, '1000': 0}
# {'env_light': 160, 'change_rate': -10}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [1.0, 0.0, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 160, 'change_rate': -8}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.8, 0.2, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 160, 'change_rate': -6}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.6, 0.4, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 160, 'change_rate': -4}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.39999999999999997, 0.6, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 160, 'change_rate': -2}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.2, 0.8, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 160, 'change_rate': 0}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.002512562814070352, 0.9949748743718593, 0.0025125628140703514]}
# Output Counts {'0001': 0, '0010': 0.00125, '0100': 0.99875, '1000': 0}
# {'env_light': 160, 'change_rate': 2}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.7999999999999999, 0.19999999999999998]}
# Output Counts {'0001': 0, '0010': 0.19328125, '0100': 0.80671875, '1000': 0}
# {'env_light': 160, 'change_rate': 4}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.6, 0.4]}
# Output Counts {'0001': 0, '0010': 0.39546875, '0100': 0.60453125, '1000': 0}
# {'env_light': 160, 'change_rate': 6}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.4, 0.6]}
# Output Counts {'0001': 0, '0010': 0.60703125, '0100': 0.39296875, '1000': 0}
# {'env_light': 160, 'change_rate': 8}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.2, 0.8]}
# Output Counts {'0001': 0, '0010': 0.79265625, '0100': 0.20734375, '1000': 0}
# {'env_light': 160, 'change_rate': 10}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.0, 1.0]}
# Output Counts {'0001': 0, '0010': 1.0, '0100': 0, '1000': 0}
# {'env_light': 170, 'change_rate': -10}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [1.0, 0.0, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 170, 'change_rate': -8}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.8, 0.2, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 170, 'change_rate': -6}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.6, 0.4, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 170, 'change_rate': -4}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.39999999999999997, 0.6, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 170, 'change_rate': -2}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.2, 0.8, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 170, 'change_rate': 0}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.002512562814070352, 0.9949748743718593, 0.0025125628140703514]}
# Output Counts {'0001': 0, '0010': 0.00203125, '0100': 0.99796875, '1000': 0}
# {'env_light': 170, 'change_rate': 2}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.7999999999999999, 0.19999999999999998]}
# Output Counts {'0001': 0, '0010': 0.20171875, '0100': 0.79828125, '1000': 0}
# {'env_light': 170, 'change_rate': 4}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.6, 0.4]}
# Output Counts {'0001': 0, '0010': 0.3975, '0100': 0.6025, '1000': 0}
# {'env_light': 170, 'change_rate': 6}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.4, 0.6]}
# Output Counts {'0001': 0, '0010': 0.60203125, '0100': 0.39796875, '1000': 0}
# {'env_light': 170, 'change_rate': 8}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.2, 0.8]}
# Output Counts {'0001': 0, '0010': 0.80375, '0100': 0.19625, '1000': 0}
# {'env_light': 170, 'change_rate': 10}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.0, 1.0]}
# Output Counts {'0001': 0, '0010': 1.0, '0100': 0, '1000': 0}
# {'env_light': 180, 'change_rate': -10}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [1.0, 0.0, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 180, 'change_rate': -8}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.8, 0.2, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 180, 'change_rate': -6}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.6, 0.4, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 180, 'change_rate': -4}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.39999999999999997, 0.6, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 180, 'change_rate': -2}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.2, 0.8, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 180, 'change_rate': 0}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.002512562814070352, 0.9949748743718593, 0.0025125628140703514]}
# Output Counts {'0001': 0, '0010': 0.00265625, '0100': 0.99734375, '1000': 0}
# {'env_light': 180, 'change_rate': 2}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.7999999999999999, 0.19999999999999998]}
# Output Counts {'0001': 0, '0010': 0.1925, '0100': 0.8075, '1000': 0}
# {'env_light': 180, 'change_rate': 4}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.6, 0.4]}
# Output Counts {'0001': 0, '0010': 0.3971875, '0100': 0.6028125, '1000': 0}
# {'env_light': 180, 'change_rate': 6}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.4, 0.6]}
# Output Counts {'0001': 0, '0010': 0.59265625, '0100': 0.40734375, '1000': 0}
# {'env_light': 180, 'change_rate': 8}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.2, 0.8]}
# Output Counts {'0001': 0, '0010': 0.79828125, '0100': 0.20171875, '1000': 0}
# {'env_light': 180, 'change_rate': 10}
# Input values  {'env_light': [0.0, 1.0, 0.0], 'change_rate': [0.0, 0.0, 1.0]}
# Output Counts {'0001': 0, '0010': 1.0, '0100': 0, '1000': 0}
# {'env_light': 190, 'change_rate': -10}
# Input values  {'env_light': [0.0, 0.9947236180904522, 0.00527638190954785], 'change_rate': [1.0, 0.0, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 190, 'change_rate': -8}
# Input values  {'env_light': [0.0, 0.9947236180904522, 0.00527638190954785], 'change_rate': [0.8, 0.2, 0.0]}
# Output Counts {'0001': 0, '0010': 0.00125, '0100': 0.99875, '1000': 0}
# {'env_light': 190, 'change_rate': -6}
# Input values  {'env_light': [0.0, 0.9947236180904522, 0.00527638190954785], 'change_rate': [0.6, 0.4, 0.0]}
# Output Counts {'0001': 0, '0010': 0.00078125, '0100': 0.99921875, '1000': 0}
# {'env_light': 190, 'change_rate': -4}
# Input values  {'env_light': [0.0, 0.9947236180904522, 0.00527638190954785], 'change_rate': [0.39999999999999997, 0.6, 0.0]}
# Output Counts {'0001': 0, '0010': 0.00171875, '0100': 0.99828125, '1000': 0}
# {'env_light': 190, 'change_rate': -2}
# Input values  {'env_light': [0.0, 0.9947236180904522, 0.00527638190954785], 'change_rate': [0.2, 0.8, 0.0]}
# Output Counts {'0001': 0, '0010': 0.00453125, '0100': 0.99546875, '1000': 0}
# {'env_light': 190, 'change_rate': 0}
# Input values  {'env_light': [0.0, 0.9947236180904522, 0.00527638190954785], 'change_rate': [0.002512562814070352, 0.9949748743718593, 0.0025125628140703514]}
# Output Counts {'0001': 0, '0010': 0.00796875, '0100': 0.99203125, '1000': 0}
# {'env_light': 190, 'change_rate': 2}
# Input values  {'env_light': [0.0, 0.9947236180904522, 0.00527638190954785], 'change_rate': [0.0, 0.7999999999999999, 0.19999999999999998]}
# Output Counts {'0001': 0.000625, '0010': 0.2053125, '0100': 0.7940625, '1000': 0}
# {'env_light': 190, 'change_rate': 4}
# Input values  {'env_light': [0.0, 0.9947236180904522, 0.00527638190954785], 'change_rate': [0.0, 0.6, 0.4]}
# Output Counts {'0001': 0.00203125, '0010': 0.398125, '0100': 0.59984375, '1000': 0}
# {'env_light': 190, 'change_rate': 6}
# Input values  {'env_light': [0.0, 0.9947236180904522, 0.00527638190954785], 'change_rate': [0.0, 0.4, 0.6]}
# Output Counts {'0001': 0.0025, '0010': 0.59953125, '0100': 0.39796875, '1000': 0}
# {'env_light': 190, 'change_rate': 8}
# Input values  {'env_light': [0.0, 0.9947236180904522, 0.00527638190954785], 'change_rate': [0.0, 0.2, 0.8]}
# Output Counts {'0001': 0.00359375, '0010': 0.8053125, '0100': 0.19109375, '1000': 0}
# {'env_light': 190, 'change_rate': 10}
# Input values  {'env_light': [0.0, 0.9947236180904522, 0.00527638190954785], 'change_rate': [0.0, 0.0, 1.0]}
# Output Counts {'0001': 0.00578125, '0010': 0.99421875, '0100': 0, '1000': 0}
# {'env_light': 200, 'change_rate': -10}
# Input values  {'env_light': [0.0, 0.49999999999999994, 0.5], 'change_rate': [1.0, 0.0, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 200, 'change_rate': -8}
# Input values  {'env_light': [0.0, 0.49999999999999994, 0.5], 'change_rate': [0.8, 0.2, 0.0]}
# Output Counts {'0001': 0, '0010': 0.0978125, '0100': 0.9021875, '1000': 0}
# {'env_light': 200, 'change_rate': -6}
# Input values  {'env_light': [0.0, 0.49999999999999994, 0.5], 'change_rate': [0.6, 0.4, 0.0]}
# Output Counts {'0001': 0, '0010': 0.194375, '0100': 0.805625, '1000': 0}
# {'env_light': 200, 'change_rate': -4}
# Input values  {'env_light': [0.0, 0.49999999999999994, 0.5], 'change_rate': [0.39999999999999997, 0.6, 0.0]}
# Output Counts {'0001': 0, '0010': 0.29109375, '0100': 0.70890625, '1000': 0}
# {'env_light': 200, 'change_rate': -2}
# Input values  {'env_light': [0.0, 0.49999999999999994, 0.5], 'change_rate': [0.2, 0.8, 0.0]}
# Output Counts {'0001': 0, '0010': 0.3940625, '0100': 0.6059375, '1000': 0}
# {'env_light': 200, 'change_rate': 0}
# Input values  {'env_light': [0.0, 0.49999999999999994, 0.5], 'change_rate': [0.002512562814070352, 0.9949748743718593, 0.0025125628140703514]}
# Output Counts {'0001': 0.0015625, '0010': 0.50515625, '0100': 0.49328125, '1000': 0}
# {'env_light': 200, 'change_rate': 2}
# Input values  {'env_light': [0.0, 0.49999999999999994, 0.5], 'change_rate': [0.0, 0.7999999999999999, 0.19999999999999998]}
# Output Counts {'0001': 0.0946875, '0010': 0.49796875, '0100': 0.40734375, '1000': 0}
# {'env_light': 200, 'change_rate': 4}
# Input values  {'env_light': [0.0, 0.49999999999999994, 0.5], 'change_rate': [0.0, 0.6, 0.4]}
# Output Counts {'0001': 0.1909375, '0010': 0.51171875, '0100': 0.29734375, '1000': 0}
# {'env_light': 200, 'change_rate': 6}
# Input values  {'env_light': [0.0, 0.49999999999999994, 0.5], 'change_rate': [0.0, 0.4, 0.6]}
# Output Counts {'0001': 0.3040625, '0010': 0.49265625, '0100': 0.20328125, '1000': 0}
# {'env_light': 200, 'change_rate': 8}
# Input values  {'env_light': [0.0, 0.49999999999999994, 0.5], 'change_rate': [0.0, 0.2, 0.8]}
# Output Counts {'0001': 0.40875, '0010': 0.48921875, '0100': 0.10203125, '1000': 0}
# {'env_light': 200, 'change_rate': 10}
# Input values  {'env_light': [0.0, 0.49999999999999994, 0.5], 'change_rate': [0.0, 0.0, 1.0]}
# Output Counts {'0001': 0.48875, '0010': 0.51125, '0100': 0, '1000': 0}
# {'env_light': 210, 'change_rate': -10}
# Input values  {'env_light': [0.0, 0.002261306532662985, 0.997738693467337], 'change_rate': [1.0, 0.0, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 210, 'change_rate': -8}
# Input values  {'env_light': [0.0, 0.002261306532662985, 0.997738693467337], 'change_rate': [0.8, 0.2, 0.0]}
# Output Counts {'0001': 0, '0010': 0.2040625, '0100': 0.7959375, '1000': 0}
# {'env_light': 210, 'change_rate': -6}
# Input values  {'env_light': [0.0, 0.002261306532662985, 0.997738693467337], 'change_rate': [0.6, 0.4, 0.0]}
# Output Counts {'0001': 0, '0010': 0.40296875, '0100': 0.59703125, '1000': 0}
# {'env_light': 210, 'change_rate': -4}
# Input values  {'env_light': [0.0, 0.002261306532662985, 0.997738693467337], 'change_rate': [0.39999999999999997, 0.6, 0.0]}
# Output Counts {'0001': 0, '0010': 0.60703125, '0100': 0.39296875, '1000': 0}
# {'env_light': 210, 'change_rate': -2}
# Input values  {'env_light': [0.0, 0.002261306532662985, 0.997738693467337], 'change_rate': [0.2, 0.8, 0.0]}
# Output Counts {'0001': 0, '0010': 0.80484375, '0100': 0.19515625, '1000': 0}
# {'env_light': 210, 'change_rate': 0}
# Input values  {'env_light': [0.0, 0.002261306532662985, 0.997738693467337], 'change_rate': [0.002512562814070352, 0.9949748743718593, 0.0025125628140703514]}
# Output Counts {'0001': 0.00265625, '0010': 0.9915625, '0100': 0.00578125, '1000': 0}
# {'env_light': 210, 'change_rate': 2}
# Input values  {'env_light': [0.0, 0.002261306532662985, 0.997738693467337], 'change_rate': [0.0, 0.7999999999999999, 0.19999999999999998]}
# Output Counts {'0001': 0.1959375, '0010': 0.8009375, '0100': 0.003125, '1000': 0}
# {'env_light': 210, 'change_rate': 4}
# Input values  {'env_light': [0.0, 0.002261306532662985, 0.997738693467337], 'change_rate': [0.0, 0.6, 0.4]}
# Output Counts {'0001': 0.3971875, '0010': 0.60203125, '0100': 0.00078125, '1000': 0}
# {'env_light': 210, 'change_rate': 6}
# Input values  {'env_light': [0.0, 0.002261306532662985, 0.997738693467337], 'change_rate': [0.0, 0.4, 0.6]}
# Output Counts {'0001': 0.60109375, '0010': 0.39828125, '0100': 0.000625, '1000': 0}
# {'env_light': 210, 'change_rate': 8}
# Input values  {'env_light': [0.0, 0.002261306532662985, 0.997738693467337], 'change_rate': [0.0, 0.2, 0.8]}
# Output Counts {'0001': 0.8096875, '0010': 0.1903125, '0100': 0, '1000': 0}
# {'env_light': 210, 'change_rate': 10}
# Input values  {'env_light': [0.0, 0.002261306532662985, 0.997738693467337], 'change_rate': [0.0, 0.0, 1.0]}
# Output Counts {'0001': 0.9978125, '0010': 0.0021875, '0100': 0, '1000': 0}
# {'env_light': 220, 'change_rate': -10}
# Input values  {'env_light': [0.0, 0.0, 1.0], 'change_rate': [1.0, 0.0, 0.0]}
# Output Counts {'0001': 0, '0010': 0, '0100': 1.0, '1000': 0}
# {'env_light': 220, 'change_rate': -8}
# Input values  {'env_light': [0.0, 0.0, 1.0], 'change_rate': [0.8, 0.2, 0.0]}
# Output Counts {'0001': 0, '0010': 0.19640625, '0100': 0.80359375, '1000': 0}
# {'env_light': 220, 'change_rate': -6}
# Input values  {'env_light': [0.0, 0.0, 1.0], 'change_rate': [0.6, 0.4, 0.0]}
# Output Counts {'0001': 0, '0010': 0.39484375, '0100': 0.60515625, '1000': 0}
# {'env_light': 220, 'change_rate': -4}
# Input values  {'env_light': [0.0, 0.0, 1.0], 'change_rate': [0.39999999999999997, 0.6, 0.0]}
# Output Counts {'0001': 0, '0010': 0.59140625, '0100': 0.40859375, '1000': 0}
# {'env_light': 220, 'change_rate': -2}
# Input values  {'env_light': [0.0, 0.0, 1.0], 'change_rate': [0.2, 0.8, 0.0]}
# Output Counts {'0001': 0, '0010': 0.804375, '0100': 0.195625, '1000': 0}
# {'env_light': 220, 'change_rate': 0}
# Input values  {'env_light': [0.0, 0.0, 1.0], 'change_rate': [0.002512562814070352, 0.9949748743718593, 0.0025125628140703514]}
# Output Counts {'0001': 0.00359375, '0010': 0.99359375, '0100': 0.0028125, '1000': 0}
# {'env_light': 220, 'change_rate': 2}
# Input values  {'env_light': [0.0, 0.0, 1.0], 'change_rate': [0.0, 0.7999999999999999, 0.19999999999999998]}
# Output Counts {'0001': 0.2028125, '0010': 0.7971875, '0100': 0, '1000': 0}
# {'env_light': 220, 'change_rate': 4}
# Input values  {'env_light': [0.0, 0.0, 1.0], 'change_rate': [0.0, 0.6, 0.4]}
# Output Counts {'0001': 0.39359375, '0010': 0.60640625, '0100': 0, '1000': 0}
# {'env_light': 220, 'change_rate': 6}
# Input values  {'env_light': [0.0, 0.0, 1.0], 'change_rate': [0.0, 0.4, 0.6]}
# Output Counts {'0001': 0.59578125, '0010': 0.40421875, '0100': 0, '1000': 0}
# {'env_light': 220, 'change_rate': 8}
# Input values  {'env_light': [0.0, 0.0, 1.0], 'change_rate': [0.0, 0.2, 0.8]}
# Output Counts {'0001': 0.81015625, '0010': 0.18984375, '0100': 0, '1000': 0}
# {'env_light': 220, 'change_rate': 10}
# Input values  {'env_light': [0.0, 0.0, 1.0], 'change_rate': [0.0, 0.0, 1.0]}
# Output Counts {'0001': 1.0, '0010': 0, '0100': 0, '1000': 0}

# %% [markdown]
# ___
#
# Then, the classical Mamdani system is implemented by using the python library Sci-kit Fuzzy. The following cells initializes the system as required from the library

# %%
from skfuzzy import control as ctrl

# %%
env_l = ctrl.Antecedent(env_light, 'env_light')
cng_r = ctrl.Antecedent(changing_rate , 'change_rate')
dim = ctrl.Consequent(dimmer_control, 'dimmer_ctrl')

env_l['dark'] = l_dark
env_l['medium'] = l_medium
env_l['light'] = l_light 

cng_r['neg_small'] = r_ns
cng_r['zero'] = r_zero
cng_r['pos_small'] = r_ps 

dim['very_small'] = dm_vs
dim['small'] = dm_s
dim['big'] = dm_b
dim['very_big'] = dm_vb


rule1 = ctrl.Rule(env_l['dark'] & cng_r['pos_small'], dim['big'])
rule2 = ctrl.Rule(env_l['dark'] & cng_r['zero'], dim['big'])
rule3 = ctrl.Rule(env_l['dark'] & cng_r['neg_small'], dim['very_big'])
rule4 = ctrl.Rule(env_l['medium'] & cng_r['pos_small'], dim['small'])
rule5 = ctrl.Rule(env_l['medium'] & cng_r['zero'], dim['big'])
rule6 = ctrl.Rule(env_l['medium'] & cng_r['neg_small'], dim['big'])
rule7 = ctrl.Rule(env_l['light'] & cng_r['pos_small'], dim['very_small'])
rule8 = ctrl.Rule(env_l['light'] & cng_r['zero'], dim['small'])
rule9 = ctrl.Rule(env_l['light'] & cng_r['neg_small'], dim['big'])

dim_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9])
dim_sys = ctrl.ControlSystemSimulation(dim_ctrl)

# %% [markdown]
# By running the following cell, the same combinations of inputs are passed to the classical control which computes the 121 output. All the output values are stored in a list.

# %%
f_classical = []
for el in el_list:
    for cr in cr_list:
        dim_sys.input['env_light']=el    
        dim_sys.input['change_rate']=cr

        dim_sys.compute()
        f_classical.append(dim_sys.output['dimmer_ctrl'])

# %% [markdown]
# At this point, both the QFIE and Classical system' control surfaces can be plotted. Firstly, the following cell shows the former surface.

# %%
from mpl_toolkits.mplot3d import Axes3D

X, Y, = el_list, cr_list
plotx,ploty, = np.meshgrid(np.linspace(np.min(X),np.max(X),11), np.linspace(np.min(Y),np.max(Y),11))
Z = np.zeros_like(plotx)
counter = 0 
for i in range(len(el_list)):
    for j in range(len(cr_list)):
        Z[i,j]=f_quantum[counter]
        counter+=1
        
zfig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(plotx, ploty, Z, rstride=1, cstride=1, cmap='viridis',
                       linewidth=0.4, antialiased=True)
ax.set_xlabel('Environment Light')
ax.set_ylabel('Changing Rate')
ax.set_zlabel('Dimmer Control')
# Out:
# Text(0.5, 0, 'Dimmer Control')

# %% [markdown]
# Then, the classical surface is displayed by running the following cell.

# %%
X, Y, = el_list, cr_list
plotx,ploty, = np.meshgrid(np.linspace(np.min(X),np.max(X),11), np.linspace(np.min(Y),np.max(Y),11))
Z = np.zeros_like(plotx)
counter = 0 
for i in range(len(el_list)):
    for j in range(len(cr_list)):
        Z[i,j]=f_classical[counter]
        counter+=1
        
zfig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(plotx, ploty, Z, rstride=1, cstride=1, cmap='viridis',
                       linewidth=0.4, antialiased=True)
ax.set_xlabel('Environment Light')
ax.set_ylabel('Changing Rate')
ax.set_zlabel('Dimmer Control')
# Out:
# Text(0.5, 0, 'Dimmer Control')

# %% [markdown]
# The two surfaces show how QFIE is able to control in a very similar way to a classical Mamdani fuzzy control the lighting control system, despite the computational advantage in firing the fuzzy rules in a parallel way.
